# %%
import pandas as pd
import requests 
from bs4 import BeautifulSoup as BS
from IPython.core.display import HTML
import json
import re

# %%
url = 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=1900-01-01&minlatitude=34.452&maxlatitude=37.44&minlongitude=-91.033&maxlongitude=-79.915&eventtype=earthquake'

# %%
#format=geojson
#eventtype=earthquake
#starttime=1900-01-01
#minlongitude-91.033
#maxlongitdue=-79.915
#maxatitude=37.44
#minlatitude=34.452

# %%
response = requests.get(url)

# %%
data = response.json()

# %%
url = 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=1900-01-01&minlatitude=34.452&maxlatitude=37.44&minlongitude=-91.033&maxlongitude=-79.915&eventtype=earthquake'

# %%
contain = []
for d in data['features']:
    d['properties']['geometry'] = d['geometry']
    d['properties']['id'] = d['id']
    contain.append(d['properties'])

# %%
full = pd.DataFrame(contain)

# %%
full['TN'] = full['place'].str.contains('Tennessee')

# %%
TN_eq = full[full['TN']==True]
#temp.query('TN == True', inplace=True)

# %%
TN_eq
# Out:
#         mag                               place           time        updated  \
# 2      2.03        6 km E of Ridgely, Tennessee  1603701334140  1603720788800
# 4      1.86      6 km ENE of Garland, Tennessee  1603685291800  1603724313790
# 7      2.45   11 km SSW of Maryville, Tennessee  1603646337880  1603813016862
# 11     1.65  5 km SSW of Tiptonville, Tennessee  1603426158260  1603471929410
# 17     1.23       7 km NW of Ridgely, Tennessee  1603249208800  1603286304430
# ...     ...                                 ...            ...            ...
# 10741   NaN                           Tennessee  -550973510000  1528145024000
# 10744  4.50                   eastern Tennessee -1298923030200  1528145024000
# 10751  4.50                           Tennessee -1616103900000  1528145024000
# 10755  4.10                   eastern Tennessee -1791252600000  1528145024000
# 10760  4.60                           Tennessee -2087790120000  1528145024000
#
#        tz                                                url  \
# 2     NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 4     NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 7     NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 11    NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 17    NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# ...    ..                                                ...
# 10741 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 10744 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 10751 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 10755 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 10760 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                                   detail  felt  cdi  mmi  ...  \
# 2      https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
# 4      https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
# 7      https://earthquake.usgs.gov/fdsnws/event/1/que...   5.0  2.7  NaN  ...
# 11     https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
# 17     https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
# ...                                                  ...   ...  ...  ...  ...
# 10741  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
# 10744  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
# 10751  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
# 10755  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
# 10760  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
#
#         nst     dmin   rms    gap magType        type  \
# 2      25.0  0.02304  0.09   60.0      md  earthquake
# 4      10.0  0.14130  0.28  233.0      md  earthquake
# 7      23.0  0.14050  0.18   80.0      md  earthquake
# 11     24.0  0.01857  0.03   47.0      md  earthquake
# 17     17.0  0.02693  0.06   65.0      md  earthquake
# ...     ...      ...   ...    ...     ...         ...
# 10741   NaN      NaN   NaN    NaN    None  earthquake
# 10744   NaN      NaN   NaN    NaN      lg  earthquake
# 10751   NaN      NaN   NaN    NaN      fa  earthquake
# 10755   NaN      NaN   NaN    NaN      fa  earthquake
# 10760   NaN      NaN   NaN    NaN      fa  earthquake
#
#                                             title  \
# 2            M 2.0 - 6 km E of Ridgely, Tennessee
# 4          M 1.9 - 6 km ENE of Garland, Tennessee
# 7       M 2.5 - 11 km SSW of Maryville, Tennessee
# 11     M 1.7 - 5 km SSW of Tiptonville, Tennessee
# 17          M 1.2 - 7 km NW of Ridgely, Tennessee
# ...                                           ...
# 10741                             M ? - Tennessee
# 10744                   M 4.5 - eastern Tennessee
# 10751                           M 4.5 - Tennessee
# 10755                   M 4.1 - eastern Tennessee
# 10760                           M 4.6 - Tennessee
#
#                                                 geometry          id    TN
# 2      {'type': 'Point', 'coordinates': [-89.4175, 36...  nm60313127  True
# 4      {'type': 'Point', 'coordinates': [-89.6906667,...  nm60313122  True
# 7      {'type': 'Point', 'coordinates': [-84.0246667,...  se60313102  True
# 11     {'type': 'Point', 'coordinates': [-89.4846667,...  nm60312902  True
# 17     {'type': 'Point', 'coordinates': [-89.5361667,...  nm60312692  True
# ...                                                  ...         ...   ...
# 10741  {'type': 'Point', 'coordinates': [-89.6, 36.2,...   ushis1786  True
# 10744  {'type': 'Point', 'coordinates': [-82.828, 36....    ushis794  True
# 10751  {'type': 'Point', 'coordinates': [-89.2, 36, N...    ushis641  True
# 10755  {'type': 'Point', 'coordinates': [-83.7, 36.2,...    ushis545  True
# 10760  {'type': 'Point', 'coordinates': [-89.5, 36.5,...    ushis422  True
#
# [4767 rows x 29 columns]

# %%
#run geospatial environment and have it plotted on the map of TN

# %%
TN_eq.query('mag>=2.5', inplace=True)
# Out:
# <ipython-input-14-d5349301630e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TN_eq.query('mag>=2.5', inplace=True)

# %%
TN_eq
# Out:
#         mag                           place           time        updated  \
# 396    2.61  7 km ENE of Seymour, Tennessee  1596420221460  1602349870040
# 440    2.53   1 km SW of Ridgely, Tennessee  1594181566140  1600549076040
# 511    2.78   8km SSE of Sewanee, Tennessee  1589099655220  1596060867040
# 512    3.13   7km SSE of Sewanee, Tennessee  1589099594740  1596060867040
# 524    2.50  4km ENE of Rutledge, Tennessee  1588151629750  1596989180713
# ...     ...                             ...            ...            ...
# 10738  3.90                       Tennessee  -465836240000  1528145024000
# 10744  4.50               eastern Tennessee -1298923030200  1528145024000
# 10751  4.50                       Tennessee -1616103900000  1528145024000
# 10755  4.10               eastern Tennessee -1791252600000  1528145024000
# 10760  4.60                       Tennessee -2087790120000  1528145024000
#
#           tz                                                url  \
# 396      NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 440      NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 511   -360.0  https://earthquake.usgs.gov/earthquakes/eventp...
# 512   -360.0  https://earthquake.usgs.gov/earthquakes/eventp...
# 524   -300.0  https://earthquake.usgs.gov/earthquakes/eventp...
# ...      ...                                                ...
# 10738    NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 10744    NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 10751    NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 10755    NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 10760    NaN  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                                   detail   felt  cdi  mmi  \
# 396    https://earthquake.usgs.gov/fdsnws/event/1/que...   34.0  4.6  NaN
# 440    https://earthquake.usgs.gov/fdsnws/event/1/que...    1.0  2.0  NaN
# 511    https://earthquake.usgs.gov/fdsnws/event/1/que...   16.0  4.6  NaN
# 512    https://earthquake.usgs.gov/fdsnws/event/1/que...  138.0  3.8  NaN
# 524    https://earthquake.usgs.gov/fdsnws/event/1/que...   89.0  3.8  NaN
# ...                                                  ...    ...  ...  ...
# 10738  https://earthquake.usgs.gov/fdsnws/event/1/que...    NaN  NaN  NaN
# 10744  https://earthquake.usgs.gov/fdsnws/event/1/que...    NaN  NaN  NaN
# 10751  https://earthquake.usgs.gov/fdsnws/event/1/que...    NaN  NaN  NaN
# 10755  https://earthquake.usgs.gov/fdsnws/event/1/que...    NaN  NaN  NaN
# 10760  https://earthquake.usgs.gov/fdsnws/event/1/que...    NaN  NaN  NaN
#
#        ...   nst      dmin   rms   gap magType        type  \
# 396    ...  28.0  0.263100  0.20  45.0      md  earthquake
# 440    ...  62.0  0.009589  0.12  28.0      md  earthquake
# 511    ...  11.0  0.084040  0.22  97.0      md  earthquake
# 512    ...  26.0  0.082200  0.18  41.0      md  earthquake
# 524    ...  22.0  0.025270  0.19  52.0      md  earthquake
# ...    ...   ...       ...   ...   ...     ...         ...
# 10738  ...   NaN       NaN   NaN   NaN      fa  earthquake
# 10744  ...   NaN       NaN   NaN   NaN      lg  earthquake
# 10751  ...   NaN       NaN   NaN   NaN      fa  earthquake
# 10755  ...   NaN       NaN   NaN   NaN      fa  earthquake
# 10760  ...   NaN       NaN   NaN   NaN      fa  earthquake
#
#                                         title  \
# 396    M 2.6 - 7 km ENE of Seymour, Tennessee
# 440     M 2.5 - 1 km SW of Ridgely, Tennessee
# 511     M 2.8 - 8km SSE of Sewanee, Tennessee
# 512     M 3.1 - 7km SSE of Sewanee, Tennessee
# 524    M 2.5 - 4km ENE of Rutledge, Tennessee
# ...                                       ...
# 10738                       M 3.9 - Tennessee
# 10744               M 4.5 - eastern Tennessee
# 10751                       M 4.5 - Tennessee
# 10755               M 4.1 - eastern Tennessee
# 10760                       M 4.6 - Tennessee
#
#                                                 geometry          id    TN
# 396    {'type': 'Point', 'coordinates': [-83.6435, 35...  se60323696  True
# 440    {'type': 'Point', 'coordinates': [-89.4991667,...  nm60299502  True
# 511    {'type': 'Point', 'coordinates': [-85.883, 35....  se60105623  True
# 512    {'type': 'Point', 'coordinates': [-85.8918333,...  se60316866  True
# 524    {'type': 'Point', 'coordinates': [-83.4638333,...  se60289532  True
# ...                                                  ...         ...   ...
# 10738  {'type': 'Point', 'coordinates': [-89.5, 36, N...   ushis2025  True
# 10744  {'type': 'Point', 'coordinates': [-82.828, 36....    ushis794  True
# 10751  {'type': 'Point', 'coordinates': [-89.2, 36, N...    ushis641  True
# 10755  {'type': 'Point', 'coordinates': [-83.7, 36.2,...    ushis545  True
# 10760  {'type': 'Point', 'coordinates': [-89.5, 36.5,...    ushis422  True
#
# [324 rows x 29 columns]
