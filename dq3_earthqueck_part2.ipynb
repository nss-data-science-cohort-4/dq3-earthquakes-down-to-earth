# %%
from bs4 import BeautifulSoup as bs
from bs4.element import Comment
import pandas as pd
import numpy as np
import requests
import seaborn as sns
import matplotlib.pyplot as plt
import json
from pandas.io.json import json_normalize
from geopandas import GeoDataFrame
from shapely.geometry import Point
import re
import folium

# %% [markdown]
# #Part 2:
#
# Use the requests library and the USGS's API (https://earthquake.usgs.gov/fdsnws/event/1/) to retrieve information about all recorded earthquakes that occurred in Tennessee since 1900. Answer the following questions:
#
# 1. How many earthquakes are in the dataset? Which region of Tennessee seems to be the most prone to earthquakes? Which is the least prone?
# 2. Do the magnitudes of earthquakes seem to follow the distribution described by Nate Silver. That is, one higher magnitude is ten times less likely to occur?

# %%
url='https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=1900-01-01&minlatitude=34.452&maxlatitude=37.44&minlongitude=-91.033&maxlongitude=-79.915&eventtype=earthquake'

# %%
usgs_response=requests.get(url)
usgs_response
# Out:
# <Response [200]>

# %%
usgs_json=usgs_response.json()

# %%
usgs_json['features']
# Out:
# [{'type': 'Feature',
#   'properties': {'mag': 2.6,
#    'place': '5 km NE of Maynard, Arkansas',
#    'time': 1603916578700,
#    'updated': 1603926441980,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60116023',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60116023&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 104,
#    'net': 'nm',
#    'code': '60116023',
#    'ids': ',nm60116023,',
#    'sources': ',nm,',
#    'types': ',origin,phase-data,',
#    'nst': 9,
#    'dmin': 0.4564,
#    'rms': 0.14,
#    'gap': 140,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.6 - 5 km NE of Maynard, Arkansas'},
#   'geometry': {'type': 'Point', 'coordinates': [-90.857, 36.459, 3.69]},
#   'id': 'nm60116023'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.64,
#    'place': '10 km NNW of Tiptonville, Tennessee',
#    'time': 1603895782690,
#    'updated': 1603906640460,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60313377',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60313377&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 41,
#    'net': 'nm',
#    'code': '60313377',
#    'ids': ',nm60313377,',
#    'sources': ',nm,',
#    'types': ',origin,phase-data,',
#    'nst': 29,
#    'dmin': 0.06686,
#    'rms': 0.03,
#    'gap': 84,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.6 - 10 km NNW of Tiptonville, Tennessee'},
#   'geometry': {'type': 'Point', 'coordinates': [-89.5168333, 36.464, 7.38]},
#   'id': 'nm60313377'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.54,
#    'place': '4 km NE of Maynard, Arkansas',
#    'time': 1603879887320,
#    'updated': 1603893061860,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60115923',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60115923&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 99,
#    'net': 'nm',
#    'code': '60115923',
#    'ids': ',nm60115923,',
#    'sources': ',nm,',
#    'types': ',origin,phase-data,',
#    'nst': 9,
#    'dmin': 0.4488,
#    'rms': 0.03,
#    'gap': 141,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.5 - 4 km NE of Maynard, Arkansas'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-90.8643333, 36.4536667, 3.42]},
#   'id': 'nm60115923'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.03,
#    'place': '0 km SSW of Sparta, North Carolina',
#    'time': 1603852792520,
#    'updated': 1603894032960,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/se60313352',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=se60313352&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 16,
#    'net': 'se',
#    'code': '60313352',
#    'ids': ',se60313352,',
#    'sources': ',se,',
#    'types': ',origin,phase-data,',
#    'nst': 6,
#    'dmin': 0.03176,
#    'rms': 0.13,
#    'gap': 206,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.0 - 0 km SSW of Sparta, North Carolina'},
#   'geometry': {'type': 'Point', 'coordinates': [-81.124, 36.4998333, 0.2]},
#   'id': 'se60313352'},
#  {'type': 'Feature',
#   'properties': {'mag': -0.67,
#    'place': '3 km SE of Sparta, North Carolina',
#    'time': 1603829850670,
#    'updated': 1603894754730,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/se60313342',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=se60313342&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 0,
#    'net': 'se',
#    'code': '60313342',
#    'ids': ',se60313342,',
#    'sources': ',se,',
#    'types': ',origin,phase-data,',
#    'nst': 4,
#    'dmin': 0.005155,
#    'rms': 0.04,
#    'gap': 141,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M -0.7 - 3 km SE of Sparta, North Carolina'},
#   'geometry': {'type': 'Point', 'coordinates': [-81.0921667, 36.4835, 1.12]},
#   'id': 'se60313342'},
#  {'type': 'Feature',
#   'properties': {'mag': -0.4,
#    'place': '3 km ENE of Sparta, North Carolina',
#    'time': 1603817138080,
#    'updated': 1603895024340,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/se60313307',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=se60313307&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 0,
#    'net': 'se',
#    'code': '60313307',
#    'ids': ',se60313307,',
#    'sources': ',se,',
#    'types': ',origin,phase-data,',
#    'nst': 4,
#    'dmin': 0.01449,
#    'rms': 0.07,
#    'gap': 284,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M -0.4 - 3 km ENE of Sparta, North Carolina'},
#   'geometry': {'type': 'Point', 'coordinates': [-81.0891667, 36.5161667, 0.2]},
#   'id': 'se60313307'},
#  {'type': 'Feature',
#   'properties': {'mag': -0.43,
#    'place': '7 km NE of Sparta, North Carolina',
#    'time': 1603794929420,
#    'updated': 1603820655300,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/se60313277',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=se60313277&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 0,
#    'net': 'se',
#    'code': '60313277',
#    'ids': ',se60313277,',
#    'sources': ',se,',
#    'types': ',origin,phase-data,',
#    'nst': 5,
#    'dmin': 0.04557,
#    'rms': 0.33,
#    'gap': 309,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M -0.4 - 7 km NE of Sparta, North Carolina'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-81.0506667, 36.5438333, 0.16]},
#   'id': 'se60313277'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.54,
#    'place': '10 km N of Dyersburg, Tennessee',
#    'time': 1603779924260,
#    'updated': 1603896667500,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60313272',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60313272&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 36,
#    'net': 'nm',
#    'code': '60313272',
#    'ids': ',nm60313272,',
#    'sources': ',nm,',
#    'types': ',origin,phase-data,',
#    'nst': 12,
#    'dmin': 0.03529,
#    'rms': 0.08,
#    'gap': 107,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.5 - 10 km N of Dyersburg, Tennessee'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-89.3751667, 36.1253333, 8.54]},
#   'id': 'nm60313272'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.53,
#    'place': '5 km ENE of Maynard, Arkansas',
#    'time': 1603756938930,
#    'updated': 1603801565010,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60115823',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60115823&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 98,
#    'net': 'nm',
#    'code': '60115823',
#    'ids': ',nm60115823,',
#    'sources': ',nm,',
#    'types': ',origin,phase-data,',
#    'nst': 11,
#    'dmin': 0.4468,
#    'rms': 0.25,
#    'gap': 136,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.5 - 5 km ENE of Maynard, Arkansas'},
#   'geometry': {'type': 'Point', 'coordinates': [-90.8415, 36.4393333, 7.92]},
#   'id': 'nm60115823'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.03,
#    'place': '6 km E of Ridgely, Tennessee',
#    'time': 1603701334140,
#    'updated': 1603720788800,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60313127',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60313127&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 63,
#    'net': 'nm',
#    'code': '60313127',
#    'ids': ',nm60313127,',
#    'sources': ',nm,',
#    'types': ',origin,phase-data,',
#    'nst': 25,
#    'dmin': 0.02304,
#    'rms': 0.09,
#    'gap': 60,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.0 - 6 km E of Ridgely, Tennessee'},
#   'geometry': {'type': 'Point', 'coordinates': [-89.4175, 36.2531667, 6.88]},
#   'id': 'nm60313127'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.44,
#    'place': '6 km E of Maynard, Arkansas',
#    'time': 1603698405230,
#    'updated': 1603725370010,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60115723',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60115723&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 92,
#    'net': 'nm',
#    'code': '60115723',
#    'ids': ',nm60115723,',
#    'sources': ',nm,',
#    'types': ',origin,phase-data,',
#    'nst': 16,
#    'dmin': 0.4433,
#    'rms': 0.18,
#    'gap': 92,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.4 - 6 km E of Maynard, Arkansas'},
#   'geometry': {'type': 'Point', 'coordinates': [-90.8248333, 36.4253333, 9.1]},
#   'id': 'nm60115723'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.86,
#    'place': '6 km ENE of Garland, Tennessee',
#    'time': 1603685291800,
#    'updated': 1603724313790,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60313122',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60313122&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 53,
#    'net': 'nm',
#    'code': '60313122',
#    'ids': ',nm60313122,',
#    'sources': ',nm,',
#    'types': ',origin,phase-data,',
#    'nst': 10,
#    'dmin': 0.1413,
#    'rms': 0.28,
#    'gap': 233,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.9 - 6 km ENE of Garland, Tennessee'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-89.6906667, 35.6151667, 1.51]},
#   'id': 'nm60313122'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.57,
#    'place': '6 km ENE of Maynard, Arkansas',
#    'time': 1603670823060,
#    'updated': 1603718153470,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60313112',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60313112&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 102,
#    'net': 'nm',
#    'code': '60313112',
#    'ids': ',nm60313112,',
#    'sources': ',nm,',
#    'types': ',origin,phase-data,',
#    'nst': 27,
#    'dmin': 0.4476,
#    'rms': 0.16,
#    'gap': 69,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.6 - 6 km ENE of Maynard, Arkansas'},
#   'geometry': {'type': 'Point', 'coordinates': [-90.829, 36.4331667, 11.8]},
#   'id': 'nm60313112'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.42,
#    'place': '6 km ENE of Maynard, Arkansas',
#    'time': 1603653013970,
#    'updated': 1603726835050,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60115728',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60115728&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 90,
#    'net': 'nm',
#    'code': '60115728',
#    'ids': ',nm60115728,',
#    'sources': ',nm,',
#    'types': ',origin,phase-data,',
#    'nst': 20,
#    'dmin': 0.4473,
#    'rms': 0.23,
#    'gap': 69,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.4 - 6 km ENE of Maynard, Arkansas'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-90.8271667, 36.4316667, 15.36]},
#   'id': 'nm60115728'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.45,
#    'place': '11 km SSW of Maryville, Tennessee',
#    'time': 1603646337880,
#    'updated': 1603813016862,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/se60313102',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=se60313102&format=geojson',
#    'felt': 5,
#    'cdi': 2.7,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 94,
#    'net': 'se',
#    'code': '60313102',
#    'ids': ',se60313102,',
#    'sources': ',se,',
#    'types': ',dyfi,origin,phase-data,',
#    'nst': 23,
#    'dmin': 0.1405,
#    'rms': 0.18,
#    'gap': 80,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.5 - 11 km SSW of Maryville, Tennessee'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-84.0246667, 35.6668333, 18.54]},
#   'id': 'se60313102'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.48,
#    'place': 'Virginia-North Carolina border region',
#    'time': 1603599003240,
#    'updated': 1603733531890,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/se60313097',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=se60313097&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 34,
#    'net': 'se',
#    'code': '60313097',
#    'ids': ',se60313097,',
#    'sources': ',se,',
#    'types': ',origin,phase-data,',
#    'nst': 6,
#    'dmin': 0.005688,
#    'rms': 0.21,
#    'gap': 263,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.5 - Virginia-North Carolina border region'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-81.0851667, 36.5016667, 1.16]},
#   'id': 'se60313097'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.72,
#    'place': '2 km ENE of Sparta, North Carolina',
#    'time': 1603597751720,
#    'updated': 1603632434150,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/se60313092',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=se60313092&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 8,
#    'net': 'se',
#    'code': '60313092',
#    'ids': ',se60313092,',
#    'sources': ',se,',
#    'types': ',origin,phase-data,',
#    'nst': 7,
#    'dmin': 0.01614,
#    'rms': 0.25,
#    'gap': 225,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.7 - 2 km ENE of Sparta, North Carolina'},
#   'geometry': {'type': 'Point', 'coordinates': [-81.0926667, 36.516, 0.09]},
#   'id': 'se60313092'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.81,
#    'place': '3 km ENE of Sparta, North Carolina',
#    'time': 1603595312000,
#    'updated': 1603864133004,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/se60313082',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=se60313082&format=geojson',
#    'felt': 389,
#    'cdi': 4.6,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 300,
#    'net': 'se',
#    'code': '60313082',
#    'ids': ',se60313082,us6000ccub,',
#    'sources': ',se,us,',
#    'types': ',dyfi,origin,phase-data,',
#    'nst': 31,
#    'dmin': 0.01259,
#    'rms': 0.11,
#    'gap': 70,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.8 - 3 km ENE of Sparta, North Carolina'},
#   'geometry': {'type': 'Point', 'coordinates': [-81.0826667, 36.5165, 1.42]},
#   'id': 'se60313082'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.65,
#    'place': '5 km SSW of Tiptonville, Tennessee',
#    'time': 1603426158260,
#    'updated': 1603471929410,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60312902',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60312902&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 42,
#    'net': 'nm',
#    'code': '60312902',
#    'ids': ',nm60312902,',
#    'sources': ',nm,',
#    'types': ',origin,phase-data,',
#    'nst': 24,
#    'dmin': 0.01857,
#    'rms': 0.03,
#    'gap': 47,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.7 - 5 km SSW of Tiptonville, Tennessee'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-89.4846667, 36.3328333, 4.93]},
#   'id': 'nm60312902'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.14,
#    'place': '2 km NNE of Cooter, Missouri',
#    'time': 1603316985720,
#    'updated': 1603370993160,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60312762',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60312762&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 70,
#    'net': 'nm',
#    'code': '60312762',
#    'ids': ',nm60312762,',
#    'sources': ',nm,',
#    'types': ',origin,phase-data,',
#    'nst': 46,
#    'dmin': 0.0643,
#    'rms': 0.1,
#    'gap': 40,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.1 - 2 km NNE of Cooter, Missouri'},
#   'geometry': {'type': 'Point', 'coordinates': [-89.8023333, 36.0705, 6.84]},
#   'id': 'nm60312762'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.69,
#    'place': '3 km E of Marston, Missouri',
#    'time': 1603312122930,
#    'updated': 1603377956660,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60312752',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60312752&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 44,
#    'net': 'nm',
#    'code': '60312752',
#    'ids': ',nm60312752,',
#    'sources': ',nm,',
#    'types': ',origin,phase-data,',
#    'nst': 19,
#    'dmin': 0.02596,
#    'rms': 0.03,
#    'gap': 50,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.7 - 3 km E of Marston, Missouri'},
#   'geometry': {'type': 'Point', 'coordinates': [-89.5691667, 36.525, 6.85]},
#   'id': 'nm60312752'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.25,
#    'place': '4 km W of Evarts, Kentucky',
#    'time': 1603294714380,
#    'updated': 1603306791529,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/se60312717',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=se60312717&format=geojson',
#    'felt': 2,
#    'cdi': 3.4,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 79,
#    'net': 'se',
#    'code': '60312717',
#    'ids': ',se60312717,',
#    'sources': ',se,',
#    'types': ',dyfi,origin,phase-data,',
#    'nst': 16,
#    'dmin': 0.375,
#    'rms': 0.32,
#    'gap': 98,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.3 - 4 km W of Evarts, Kentucky'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-83.2428333, 36.8671667, 9.37]},
#   'id': 'se60312717'},
#  {'type': 'Feature',
#   'properties': {'mag': -0.67,
#    'place': '2 km SSE of Sparta, North Carolina',
#    'time': 1603273484720,
#    'updated': 1603283517890,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/se60312707',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=se60312707&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 0,
#    'net': 'se',
#    'code': '60312707',
#    'ids': ',se60312707,',
#    'sources': ',se,',
#    'types': ',origin,phase-data,',
#    'nst': 4,
#    'dmin': 0.01516,
#    'rms': 0.01,
#    'gap': 183,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M -0.7 - 2 km SSE of Sparta, North Carolina'},
#   'geometry': {'type': 'Point', 'coordinates': [-81.1106667, 36.4865, 0.74]},
#   'id': 'se60312707'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.61,
#    'place': '4 km NW of Marston, Missouri',
#    'time': 1603256151350,
#    'updated': 1603285497100,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60312697',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60312697&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 40,
#    'net': 'nm',
#    'code': '60312697',
#    'ids': ',nm60312697,',
#    'sources': ',nm,',
#    'types': ',origin,phase-data,',
#    'nst': 24,
#    'dmin': 0.02245,
#    'rms': 0.04,
#    'gap': 44,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.6 - 4 km NW of Marston, Missouri'},
#   'geometry': {'type': 'Point', 'coordinates': [-89.649, 36.5456667, 8.01]},
#   'id': 'nm60312697'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.23,
#    'place': '7 km NW of Ridgely, Tennessee',
#    'time': 1603249208800,
#    'updated': 1603286304430,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60312692',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60312692&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 23,
#    'net': 'nm',
#    'code': '60312692',
#    'ids': ',nm60312692,',
#    'sources': ',nm,',
#    'types': ',origin,phase-data,',
#    'nst': 17,
#    'dmin': 0.02693,
#    'rms': 0.06,
#    'gap': 65,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.2 - 7 km NW of Ridgely, Tennessee'},
#   'geometry': {'type': 'Point', 'coordinates': [-89.5361667, 36.3136667, 9.5]},
#   'id': 'nm60312692'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.19,
#    'place': '3 km SE of Sparta, North Carolina',
#    'time': 1603248748740,
#    'updated': 1603289284520,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/se60312687',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=se60312687&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 1,
#    'net': 'se',
#    'code': '60312687',
#    'ids': ',se60312687,',
#    'sources': ',se,',
#    'types': ',origin,phase-data,',
#    'nst': 6,
#    'dmin': 0.0071,
#    'rms': 0.01,
#    'gap': 123,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.2 - 3 km SE of Sparta, North Carolina'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-81.1001667, 36.4841667, 7.18]},
#   'id': 'se60312687'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.33,
#    'place': '3 km W of Ridgely, Tennessee',
#    'time': 1603219821800,
#    'updated': 1603283375220,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60312672',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60312672&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 84,
#    'net': 'nm',
#    'code': '60312672',
#    'ids': ',nm60312672,',
#    'sources': ',nm,',
#    'types': ',origin,phase-data,',
#    'nst': 46,
#    'dmin': 0.0152,
#    'rms': 0.11,
#    'gap': 33,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.3 - 3 km W of Ridgely, Tennessee'},
#   'geometry': {'type': 'Point', 'coordinates': [-89.5233333, 36.2675, 8.84]},
#   'id': 'nm60312672'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.48,
#    'place': '9 km SE of Marston, Missouri',
#    'time': 1603169817790,
#    'updated': 1603212636840,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60312667',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60312667&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 34,
#    'net': 'nm',
#    'code': '60312667',
#    'ids': ',nm60312667,',
#    'sources': ',nm,',
#    'types': ',origin,phase-data,',
#    'nst': 26,
#    'dmin': 0.07238,
#    'rms': 0.05,
#    'gap': 42,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.5 - 9 km SE of Marston, Missouri'},
#   'geometry': {'type': 'Point', 'coordinates': [-89.5321667, 36.458, 8.67]},
#   'id': 'nm60312667'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.3,
#    'place': '5 km NNW of Tiptonville, Tennessee',
#    'time': 1603139476660,
#    'updated': 1603220770270,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60312652',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60312652&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 26,
#    'net': 'nm',
#    'code': '60312652',
#    'ids': ',nm60312652,',
#    'sources': ',nm,',
#    'types': ',origin,phase-data,',
#    'nst': 16,
#    'dmin': 0.03247,
#    'rms': 0.02,
#    'gap': 87,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 5 km NNW of Tiptonville, Tennessee'},
#   'geometry': {'type': 'Point', 'coordinates': [-89.499, 36.4196667, 7.78]},
#   'id': 'nm60312652'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.31,
#    'place': '6 km N of Greeneville, Tennessee',
#    'time': 1603138778490,
#    'updated': 1603435975336,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/se60115423',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=se60115423&format=geojson',
#    'felt': 5,
#    'cdi': 3.4,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 84,
#    'net': 'se',
#    'code': '60115423',
#    'ids': ',se60115423,',
#    'sources': ',se,',
#    'types': ',dyfi,origin,phase-data,',
#    'nst': 8,
#    'dmin': 0.1751,
#    'rms': 0.12,
#    'gap': 70,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.3 - 6 km N of Greeneville, Tennessee'},
#   'geometry': {'type': 'Point', 'coordinates': [-82.8171667, 36.224, 17.27]},
#   'id': 'se60115423'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.59,
#    'place': '6 km S of Ridgely, Tennessee',
#    'time': 1603084525090,
#    'updated': 1603112625780,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60312582',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60312582&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 39,
#    'net': 'nm',
#    'code': '60312582',
#    'ids': ',nm60312582,',
#    'sources': ',nm,',
#    'types': ',origin,phase-data,',
#    'nst': 16,
#    'dmin': 0.04374,
#    'rms': 0.05,
#    'gap': 59,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.6 - 6 km S of Ridgely, Tennessee'},
#   'geometry': {'type': 'Point', 'coordinates': [-89.4761667, 36.2095, 6.33]},
#   'id': 'nm60312582'},
#  {'type': 'Feature',
#   'properties': {'mag': -0.61,
#    'place': '4 km ESE of Sparta, North Carolina',
#    'time': 1603040052390,
#    'updated': 1603113038350,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/se60312572',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=se60312572&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 0,
#    'net': 'se',
#    'code': '60312572',
#    'ids': ',se60312572,',
#    'sources': ',se,',
#    'types': ',origin,phase-data,',
#    'nst': 4,
#    'dmin': 0.01236,
#    'rms': 0.03,
#    'gap': 147,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M -0.6 - 4 km ESE of Sparta, North Carolina'},
#   'geometry': {'type': 'Point', 'coordinates': [-81.082, 36.4858333, 0.71]},
#   'id': 'se60312572'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.22,
#    'place': '3 km ENE of Lilbourn, Missouri',
#    'time': 1602965351850,
#    'updated': 1603116525320,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60312517',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60312517&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 23,
#    'net': 'nm',
#    'code': '60312517',
#    'ids': ',nm60312517,',
#    'sources': ',nm,',
#    'types': ',origin,phase-data,',
#    'nst': 18,
#    'dmin': 0.02594,
#    'rms': 0.07,
#    'gap': 51,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.2 - 3 km ENE of Lilbourn, Missouri'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-89.5796667, 36.6013333, 10.79]},
#   'id': 'nm60312517'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.26,
#    'place': '4 km NNW of Flat Top Mountain, Tennessee',
#    'time': 1602918764060,
#    'updated': 1602942888250,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/se60312452',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=se60312452&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 79,
#    'net': 'se',
#    'code': '60312452',
#    'ids': ',se60312452,',
#    'sources': ',se,',
#    'types': ',origin,phase-data,',
#    'nst': 16,
#    'dmin': 0.1587,
#    'rms': 0.14,
#    'gap': 59,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.3 - 4 km NNW of Flat Top Mountain, Tennessee'},
#   'geometry': {'type': 'Point', 'coordinates': [-85.2135, 35.3668333, 17.99]},
#   'id': 'se60312452'},
#  {'type': 'Feature',
#   'properties': {'mag': -0.33,
#    'place': '3 km E of Sparta, North Carolina',
#    'time': 1602825373960,
#    'updated': 1602857722660,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/se60312382',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=se60312382&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 0,
#    'net': 'se',
#    'code': '60312382',
#    'ids': ',se60312382,',
#    'sources': ',se,',
#    'types': ',origin,phase-data,',
#    'nst': 5,
#    'dmin': 0.007472,
#    'rms': 0.2,
#    'gap': 272,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M -0.3 - 3 km E of Sparta, North Carolina'},
#   'geometry': {'type': 'Point', 'coordinates': [-81.0848333, 36.51, 5.26]},
#   'id': 'se60312382'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.16,
#    'place': '9 km ENE of Steele, Missouri',
#    'time': 1602815316570,
#    'updated': 1602857004840,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60312372',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60312372&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 72,
#    'net': 'nm',
#    'code': '60312372',
#    'ids': ',nm60312372,',
#    'sources': ',nm,',
#    'types': ',origin,phase-data,',
#    'nst': 32,
#    'dmin': 0.02656,
#    'rms': 0.03,
#    'gap': 36,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.2 - 9 km ENE of Steele, Missouri'},
#   'geometry': {'type': 'Point', 'coordinates': [-89.7346667, 36.1175, 9.95]},
#   'id': 'nm60312372'},
#  {'type': 'Feature',
#   'properties': {'mag': -0.67,
#    'place': '4 km SE of Sparta, North Carolina',
#    'time': 1602802615610,
#    'updated': 1602858004400,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/se60312367',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=se60312367&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 0,
#    'net': 'se',
#    'code': '60312367',
#    'ids': ',se60312367,',
#    'sources': ',se,',
#    'types': ',origin,phase-data,',
#    'nst': 4,
#    'dmin': 0.008929,
#    'rms': 0.05,
#    'gap': 133,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M -0.7 - 4 km SE of Sparta, North Carolina'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-81.0856667, 36.4733333, 2.34]},
#   'id': 'se60312367'},
#  {'type': 'Feature',
#   'properties': {'mag': -0.56,
#    'place': '4 km SE of Sparta, North Carolina',
#    'time': 1602734685570,
#    'updated': 1602773384900,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/se60312297',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=se60312297&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 0,
#    'net': 'se',
#    'code': '60312297',
#    'ids': ',se60312297,',
#    'sources': ',se,',
#    'types': ',origin,phase-data,',
#    'nst': 4,
#    'dmin': 0.008551,
#    'rms': 0.04,
#    'gap': 140,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M -0.6 - 4 km SE of Sparta, North Carolina'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-81.0876667, 36.4721667, 2.71]},
#   'id': 'se60312297'},
#  {'type': 'Feature',
#   'properties': {'mag': -0.56,
#    'place': '3 km SE of Sparta, North Carolina',
#    'time': 1602648131660,
#    'updated': 1602693304090,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/se60312152',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=se60312152&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 0,
#    'net': 'se',
#    'code': '60312152',
#    'ids': ',se60312152,',
#    'sources': ',se,',
#    'types': ',origin,phase-data,',
#    'nst': 4,
#    'dmin': 0.005241,
#    'rms': 0.05,
#    'gap': 127,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M -0.6 - 3 km SE of Sparta, North Carolina'},
#   'geometry': {'type': 'Point', 'coordinates': [-81.0885, 36.4806667, 1.3]},
#   'id': 'se60312152'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.83,
#    'place': '9 km SW of Caruthersville, Missouri',
#    'time': 1602634382350,
#    'updated': 1602776923200,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60312142',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60312142&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 52,
#    'net': 'nm',
#    'code': '60312142',
#    'ids': ',nm60312142,',
#    'sources': ',nm,',
#    'types': ',origin,phase-data,',
#    'nst': 33,
#    'dmin': 0.01221,
#    'rms': 0.22,
#    'gap': 57,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.8 - 9 km SW of Caruthersville, Missouri'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-89.7156667, 36.1251667, 10.16]},
#   'id': 'nm60312142'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.51,
#    'place': '6 km E of Maynard, Arkansas',
#    'time': 1602625694120,
#    'updated': 1602712862040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60115023',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60115023&format=geojson',
#    'felt': 1,
#    'cdi': 2,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 97,
#    'net': 'nm',
#    'code': '60115023',
#    'ids': ',nm60115023,us6000c8b3,',
#    'sources': ',nm,us,',
#    'types': ',dyfi,origin,phase-data,',
#    'nst': 6,
#    'dmin': 0.4454,
#    'rms': 0.22,
#    'gap': 154,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.5 - 6 km E of Maynard, Arkansas'},
#   'geometry': {'type': 'Point', 'coordinates': [-90.8283333, 36.43, 10.08]},
#   'id': 'nm60115023'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.94,
#    'place': '2 km NNE of Cooter, Missouri',
#    'time': 1602617591600,
#    'updated': 1602679115270,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60312087',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60312087&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 58,
#    'net': 'nm',
#    'code': '60312087',
#    'ids': ',nm60312087,',
#    'sources': ',nm,',
#    'types': ',origin,phase-data,',
#    'nst': 22,
#    'dmin': 0.06515,
#    'rms': 0.11,
#    'gap': 50,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.9 - 2 km NNE of Cooter, Missouri'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-89.8033333, 36.0683333, 6.88]},
#   'id': 'nm60312087'},
#  {'type': 'Feature',
#   'properties': {'mag': -0.85,
#    'place': '3 km SSE of Sparta, North Carolina',
#    'time': 1602605031660,
#    'updated': 1602693501530,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/se60312077',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=se60312077&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 0,
#    'net': 'se',
#    'code': '60312077',
#    'ids': ',se60312077,',
#    'sources': ',se,',
#    'types': ',origin,phase-data,',
#    'nst': 4,
#    'dmin': 0.007639,
#    'rms': 0.03,
#    'gap': 143,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M -0.9 - 3 km SSE of Sparta, North Carolina'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-81.1021667, 36.4741667, 0.08]},
#   'id': 'se60312077'},
#  {'type': 'Feature',
#   'properties': {'mag': -0.4,
#    'place': '3 km ENE of Sparta, North Carolina',
#    'time': 1602595327710,
#    'updated': 1602605492780,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/se60312067',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=se60312067&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 0,
#    'net': 'se',
#    'code': '60312067',
#    'ids': ',se60312067,',
#    'sources': ',se,',
#    'types': ',origin,phase-data,',
#    'nst': 4,
#    'dmin': 0.01276,
#    'rms': 0.06,
#    'gap': 292,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M -0.4 - 3 km ENE of Sparta, North Carolina'},
#   'geometry': {'type': 'Point', 'coordinates': [-81.0851667, 36.516, 0.09]},
#   'id': 'se60312067'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.4,
#    'place': '9 km SW of Sparta, North Carolina',
#    'time': 1602593467130,
#    'updated': 1602679821450,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/se60312062',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=se60312062&format=geojson',
#    'felt': 19,
#    'cdi': 3.4,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 95,
#    'net': 'se',
#    'code': '60312062',
#    'ids': ',se60312062,us6000c803,',
#    'sources': ',se,us,',
#    'types': ',dyfi,origin,phase-data,',
#    'nst': 15,
#    'dmin': 0.04533,
#    'rms': 0.17,
#    'gap': 84,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.4 - 9 km SW of Sparta, North Carolina'},
#   'geometry': {'type': 'Point', 'coordinates': [-81.1933333, 36.4395, 6.24]},
#   'id': 'se60312062'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.55,
#    'place': '7 km SW of Sparta, North Carolina',
#    'time': 1602581048740,
#    'updated': 1602605938950,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/se60312057',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=se60312057&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 5,
#    'net': 'se',
#    'code': '60312057',
#    'ids': ',se60312057,',
#    'sources': ',se,',
#    'types': ',origin,phase-data,',
#    'nst': 6,
#    'dmin': 0.0288,
#    'rms': 0.04,
#    'gap': 176,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.6 - 7 km SW of Sparta, North Carolina'},
#   'geometry': {'type': 'Point', 'coordinates': [-81.1815, 36.4651667, 7.86]},
#   'id': 'se60312057'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.78,
#    'place': '6 km SW of Sparta, North Carolina',
#    'time': 1602580482920,
#    'updated': 1602606549940,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/se60312052',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=se60312052&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 49,
#    'net': 'se',
#    'code': '60312052',
#    'ids': ',se60312052,',
#    'sources': ',se,',
#    'types': ',origin,phase-data,',
#    'nst': 9,
#    'dmin': 0.028,
#    'rms': 0.05,
#    'gap': 139,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.8 - 6 km SW of Sparta, North Carolina'},
#   'geometry': {'type': 'Point', 'coordinates': [-81.1805, 36.4653333, 7.7]},
#   'id': 'se60312052'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.38,
#    'place': '7 km SW of Sparta, North Carolina',
#    'time': 1602560205610,
#    'updated': 1602607554510,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/se60312047',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=se60312047&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 29,
#    'net': 'se',
#    'code': '60312047',
#    'ids': ',se60312047,',
#    'sources': ',se,',
#    'types': ',origin,phase-data,',
#    'nst': 9,
#    'dmin': 0.03083,
#    'rms': 0.01,
#    'gap': 139,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.4 - 7 km SW of Sparta, North Carolina'},
#   'geometry': {'type': 'Point', 'coordinates': [-81.184, 36.4655, 7.44]},
#   'id': 'se60312047'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.27,
#    'place': '7 km SW of Sparta, North Carolina',
#    'time': 1602557904110,
#    'updated': 1602608085940,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/se60312042',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=se60312042&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 25,
#    'net': 'se',
#    'code': '60312042',
#    'ids': ',se60312042,',
#    'sources': ',se,',
#    'types': ',origin,phase-data,',
#    'nst': 7,
#    'dmin': 0.02813,
#    'rms': 0.03,
#    'gap': 178,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 7 km SW of Sparta, North Carolina'},
#   'geometry': {'type': 'Point', 'coordinates': [-81.1805, 36.4606667, 7.6]},
#   'id': 'se60312042'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.97,
#    'place': 'Virginia-North Carolina border region',
#    'time': 1602557632940,
#    'updated': 1602605331273,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/se60312037',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=se60312037&format=geojson',
#    'felt': 3,
#    'cdi': 2,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 60,
#    'net': 'se',
#    'code': '60312037',
#    'ids': ',se60312037,',
#    'sources': ',se,',
#    'types': ',dyfi,origin,phase-data,',
#    'nst': 11,
#    'dmin': 0.04248,
#    'rms': 0.11,
#    'gap': 145,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.0 - Virginia-North Carolina border region'},
#   'geometry': {'type': 'Point', 'coordinates': [-81.1975, 36.4555, 6.82]},
#   'id': 'se60312037'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.25,
#    'place': '13 km NNW of Dyersburg, Tennessee',
#    'time': 1602550477140,
#    'updated': 1602783407360,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60312032',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60312032&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 24,
#    'net': 'nm',
#    'code': '60312032',
#    'ids': ',nm60312032,',
#    'sources': ',nm,',
#    'types': ',origin,phase-data,',
#    'nst': 16,
#    'dmin': 0.04641,
#    'rms': 0.16,
#    'gap': 58,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 13 km NNW of Dyersburg, Tennessee'},
#   'geometry': {'type': 'Point', 'coordinates': [-89.4576667, 36.1415, 11.47]},
#   'id': 'nm60312032'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.06,
#    'place': '10 km SSE of Ridgely, Tennessee',
#    'time': 1602513702180,
#    'updated': 1602516546870,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60311932',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60311932&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 65,
#    'net': 'nm',
#    'code': '60311932',
#    'ids': ',nm60311932,',
#    'sources': ',nm,',
#    'types': ',origin,phase-data,',
#    'nst': 36,
#    'dmin': 0.03136,
#    'rms': 0.07,
#    'gap': 44,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.1 - 10 km SSE of Ridgely, Tennessee'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-89.4633333, 36.1688333, 11.87]},
#   'id': 'nm60311932'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.33,
#    'place': '5 km SW of Tiptonville, Tennessee',
#    'time': 1602502400900,
#    'updated': 1602509277710,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60311927',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60311927&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 27,
#    'net': 'nm',
#    'code': '60311927',
#    'ids': ',nm60311927,',
#    'sources': ',nm,',
#    'types': ',origin,phase-data,',
#    'nst': 15,
#    'dmin': 0.01536,
#    'rms': 0.04,
#    'gap': 75,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 5 km SW of Tiptonville, Tennessee'},
#   'geometry': {'type': 'Point', 'coordinates': [-89.5166667, 36.345, 5.33]},
#   'id': 'nm60311927'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.45,
#    'place': '5 km NW of Ridgely, Tennessee',
#    'time': 1602481033920,
#    'updated': 1602509731180,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60311917',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60311917&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 32,
#    'net': 'nm',
#    'code': '60311917',
#    'ids': ',nm60311917,',
#    'sources': ',nm,',
#    'types': ',origin,phase-data,',
#    'nst': 18,
#    'dmin': 0.03705,
#    'rms': 0.06,
#    'gap': 49,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.5 - 5 km NW of Ridgely, Tennessee'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-89.5356667, 36.2971667, 10.26]},
#   'id': 'nm60311917'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.39,
#    'place': '5 km NW of Ridgely, Tennessee',
#    'time': 1602476187060,
#    'updated': 1602510468640,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60311907',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60311907&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 30,
#    'net': 'nm',
#    'code': '60311907',
#    'ids': ',nm60311907,',
#    'sources': ',nm,',
#    'types': ',origin,phase-data,',
#    'nst': 21,
#    'dmin': 0.03885,
#    'rms': 0.07,
#    'gap': 49,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.4 - 5 km NW of Ridgely, Tennessee'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-89.5341667, 36.2958333, 9.91]},
#   'id': 'nm60311907'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.63,
#    'place': '6 km ENE of Maynard, Arkansas',
#    'time': 1602466546340,
#    'updated': 1602625101040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60311892',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60311892&format=geojson',
#    'felt': 2,
#    'cdi': 2.2,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 107,
#    'net': 'nm',
#    'code': '60311892',
#    'ids': ',nm60311892,us6000c7my,',
#    'sources': ',nm,us,',
#    'types': ',dyfi,origin,phase-data,',
#    'nst': 30,
#    'dmin': 0.4503,
#    'rms': 0.2,
#    'gap': 69,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.6 - 6 km ENE of Maynard, Arkansas'},
#   'geometry': {'type': 'Point', 'coordinates': [-90.831, 36.4376667, 9.91]},
#   'id': 'nm60311892'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.53,
# ...
#    'tsunami': 0,
#    'sig': 25,
#    'net': 'se',
#    'code': '60277201',
#    'ids': ',se60277201,',
#    'sources': ',se,',
#    'types': ',geoserve,origin,phase-data,',
#    'nst': 7,
#    'dmin': 0.03583,
#    'rms': 0.09,
#    'gap': 112,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 0km NNE of Englewood, Tennessee'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-84.4858333, 35.4296667, 17.44]},
#   'id': 'se60277201'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.38,
#    'place': '12km SW of Blytheville, Arkansas',
#    'time': 1560569253360,
#    'updated': 1567779907040,
#    'tz': -360,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60276986',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60276986&format=geojson',
#    'felt': 3,
#    'cdi': 2.2,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 88,
#    'net': 'nm',
#    'code': '60276986',
#    'ids': ',nm60276986,us6000411d,',
#    'sources': ',nm,us,',
#    'types': ',dyfi,geoserve,origin,phase-data,',
#    'nst': 43,
#    'dmin': 0.04019,
#    'rms': 0.25,
#    'gap': 50,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.4 - 12km SW of Blytheville, Arkansas'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-90.0293333, 35.8463333, 10.11]},
#   'id': 'nm60276986'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.38,
#    'place': '16km N of Scottsboro, Alabama',
#    'time': 1560272547670,
#    'updated': 1560290505178,
#    'tz': -360,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/se60251142',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=se60251142&format=geojson',
#    'felt': 2,
#    'cdi': 1,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 87,
#    'net': 'se',
#    'code': '60251142',
#    'ids': ',se60251142,',
#    'sources': ',se,',
#    'types': ',dyfi,geoserve,origin,phase-data,',
#    'nst': 13,
#    'dmin': 0.4026,
#    'rms': 0.18,
#    'gap': 78,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.4 - 16km N of Scottsboro, Alabama'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-86.0208333, 34.8191667, 12.45]},
#   'id': 'se60251142'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.43,
#    'place': '6km SSE of Ridgely, Tennessee',
#    'time': 1560258297750,
#    'updated': 1560267493900,
#    'tz': -360,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60251102',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60251102&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 31,
#    'net': 'nm',
#    'code': '60251102',
#    'ids': ',nm60251102,',
#    'sources': ',nm,',
#    'types': ',geoserve,origin,phase-data,',
#    'nst': 14,
#    'dmin': 0.02943,
#    'rms': 0.04,
#    'gap': 81,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.4 - 6km SSE of Ridgely, Tennessee'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-89.4513333, 36.2146667, 8.99]},
#   'id': 'nm60251102'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.16,
#    'place': '5km S of Sweetwater, Tennessee',
#    'time': 1560257530500,
#    'updated': 1567779933040,
#    'tz': -300,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/se60251097',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=se60251097&format=geojson',
#    'felt': 5,
#    'cdi': 2.7,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 73,
#    'net': 'se',
#    'code': '60251097',
#    'ids': ',se60251097,us70003y3q,',
#    'sources': ',se,us,',
#    'types': ',dyfi,geoserve,origin,phase-data,',
#    'nst': 14,
#    'dmin': 0.1146,
#    'rms': 0.05,
#    'gap': 75,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.2 - 5km S of Sweetwater, Tennessee'},
#   'geometry': {'type': 'Point', 'coordinates': [-84.466, 35.5553333, 8.58]},
#   'id': 'se60251097'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.58,
#    'place': '7km ESE of Vonore, Tennessee',
#    'time': 1560239306940,
#    'updated': 1560290567923,
#    'tz': -300,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/se60084523',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=se60084523&format=geojson',
#    'felt': 1,
#    'cdi': 1,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 39,
#    'net': 'se',
#    'code': '60084523',
#    'ids': ',se60084523,',
#    'sources': ',se,',
#    'types': ',dyfi,geoserve,origin,phase-data,',
#    'nst': 8,
#    'dmin': 0.1126,
#    'rms': 0.21,
#    'gap': 88,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.6 - 7km ESE of Vonore, Tennessee'},
#   'geometry': {'type': 'Point', 'coordinates': [-84.1605, 35.5651667, 11.85]},
#   'id': 'se60084523'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.15,
#    'place': '10km W of Loretto, Tennessee',
#    'time': 1560166831900,
#    'updated': 1566928087040,
#    'tz': -360,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/se60084338',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=se60084338&format=geojson',
#    'felt': 2,
#    'cdi': 2.2,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 72,
#    'net': 'se',
#    'code': '60084338',
#    'ids': ',se60084338,us70003xmx,',
#    'sources': ',se,us,',
#    'types': ',dyfi,geoserve,origin,phase-data,',
#    'nst': 7,
#    'dmin': 0.4287,
#    'rms': 0.33,
#    'gap': 104,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.2 - 10km W of Loretto, Tennessee'},
#   'geometry': {'type': 'Point', 'coordinates': [-87.5585, 35.0885, 2.02]},
#   'id': 'se60084338'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.27,
#    'place': '6km WNW of Reed Creek, Georgia',
#    'time': 1560135082730,
#    'updated': 1566928083040,
#    'tz': -300,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/se60084333',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=se60084333&format=geojson',
#    'felt': 19,
#    'cdi': 3.8,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 86,
#    'net': 'se',
#    'code': '60084333',
#    'ids': ',se60084333,us70003xmp,',
#    'sources': ',se,us,',
#    'types': ',dyfi,geoserve,origin,phase-data,',
#    'nst': 15,
#    'dmin': 0.5367,
#    'rms': 0.35,
#    'gap': 105,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.3 - 6km WNW of Reed Creek, Georgia'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-82.9771667, 34.4563333, 0.05]},
#   'id': 'se60084333'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.59,
#    'place': '12km NW of Tiptonville, Tennessee',
#    'time': 1560091186210,
#    'updated': 1560449388720,
#    'tz': -360,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60250912',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60250912&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 39,
#    'net': 'nm',
#    'code': '60250912',
#    'ids': ',nm60250912,',
#    'sources': ',nm,',
#    'types': ',geoserve,origin,phase-data,',
#    'nst': 23,
#    'dmin': 0.06444,
#    'rms': 0.04,
#    'gap': 54,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.6 - 12km NW of Tiptonville, Tennessee'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-89.5516667, 36.4691667, 9.42]},
#   'id': 'nm60250912'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.46,
#    'place': '11km NW of Luxora, Arkansas',
#    'time': 1560074679970,
#    'updated': 1561487794270,
#    'tz': -360,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60085023',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60085023&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 33,
#    'net': 'nm',
#    'code': '60085023',
#    'ids': ',nm60085023,',
#    'sources': ',nm,',
#    'types': ',geoserve,origin,phase-data,',
#    'nst': 5,
#    'dmin': 0.02372,
#    'rms': 0.11,
#    'gap': 117,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.5 - 11km NW of Luxora, Arkansas'},
#   'geometry': {'type': 'Point', 'coordinates': [-90.0328333, 35.8225, 8.5]},
#   'id': 'nm60085023'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.29,
#    'place': '11km E of Tiptonville, Tennessee',
#    'time': 1560074265630,
#    'updated': 1560451829760,
#    'tz': -360,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60250897',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60250897&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 81,
#    'net': 'nm',
#    'code': '60250897',
#    'ids': ',nm60250897,',
#    'sources': ',nm,',
#    'types': ',geoserve,origin,phase-data,',
#    'nst': 32,
#    'dmin': 0.03076,
#    'rms': 0.13,
#    'gap': 130,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.3 - 11km E of Tiptonville, Tennessee'},
#   'geometry': {'type': 'Point', 'coordinates': [-89.339, 36.3818333, 4.09]},
#   'id': 'nm60250897'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.15,
#    'place': '4km NE of Steele, Missouri',
#    'time': 1559936093640,
#    'updated': 1560449648420,
#    'tz': -360,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60250707',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60250707&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 20,
#    'net': 'nm',
#    'code': '60250707',
#    'ids': ',nm60250707,',
#    'sources': ',nm,',
#    'types': ',geoserve,origin,phase-data,',
#    'nst': 6,
#    'dmin': 0.0623,
#    'rms': 0.23,
#    'gap': 147,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.2 - 4km NE of Steele, Missouri'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-89.7851667, 36.1096667, 12.41]},
#   'id': 'nm60250707'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.23,
#    'place': '5km NNW of Ridgely, Tennessee',
#    'time': 1559881153220,
#    'updated': 1560450006370,
#    'tz': -360,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60250462',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60250462&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 23,
#    'net': 'nm',
#    'code': '60250462',
#    'ids': ',nm60250462,',
#    'sources': ',nm,',
#    'types': ',geoserve,origin,phase-data,',
#    'nst': 10,
#    'dmin': 0.0419,
#    'rms': 0.2,
#    'gap': 111,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.2 - 5km NNW of Ridgely, Tennessee'},
#   'geometry': {'type': 'Point', 'coordinates': [-89.5203333, 36.3056667, 5.7]},
#   'id': 'nm60250462'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.03,
#    'place': '8km WSW of Metropolis, Illinois',
#    'time': 1559864058590,
#    'updated': 1566928062040,
#    'tz': -360,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60250332',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60250332&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 63,
#    'net': 'nm',
#    'code': '60250332',
#    'ids': ',nm60250332,us70003wj3,',
#    'sources': ',nm,us,',
#    'types': ',geoserve,origin,phase-data,',
#    'nst': 42,
#    'dmin': 0.07616,
#    'rms': 0.21,
#    'gap': 82,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.0 - 8km WSW of Metropolis, Illinois'},
#   'geometry': {'type': 'Point', 'coordinates': [-88.823, 37.1328333, 3.86]},
#   'id': 'nm60250332'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.59,
#    'place': '2km NE of Caruthersville, Missouri',
#    'time': 1559731534150,
#    'updated': 1561641297730,
#    'tz': -360,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60250027',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60250027&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 39,
#    'net': 'nm',
#    'code': '60250027',
#    'ids': ',nm60250027,',
#    'sources': ',nm,',
#    'types': ',geoserve,origin,phase-data,',
#    'nst': 10,
#    'dmin': 0.05803,
#    'rms': 0.04,
#    'gap': 77,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.6 - 2km NE of Caruthersville, Missouri'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-89.6296667, 36.2071667, 6.18]},
#   'id': 'nm60250027'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.26,
#    'place': '7km SE of Ridgely, Tennessee',
#    'time': 1559708725660,
#    'updated': 1561645987920,
#    'tz': -360,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60250022',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60250022&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 24,
#    'net': 'nm',
#    'code': '60250022',
#    'ids': ',nm60250022,',
#    'sources': ',nm,',
#    'types': ',geoserve,origin,phase-data,',
#    'nst': 8,
#    'dmin': 0.009767,
#    'rms': 0.03,
#    'gap': 79,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 7km SE of Ridgely, Tennessee'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-89.4266667, 36.2218333, 7.36]},
#   'id': 'nm60250022'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.69,
#    'place': '6km NW of Ridgely, Tennessee',
#    'time': 1559543813720,
#    'updated': 1561649172430,
#    'tz': -360,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60249032',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60249032&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 44,
#    'net': 'nm',
#    'code': '60249032',
#    'ids': ',nm60249032,',
#    'sources': ',nm,',
#    'types': ',geoserve,origin,phase-data,',
#    'nst': 20,
#    'dmin': 0.03606,
#    'rms': 0.1,
#    'gap': 50,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.7 - 6km NW of Ridgely, Tennessee'},
#   'geometry': {'type': 'Point', 'coordinates': [-89.5266667, 36.3085, 6.56]},
#   'id': 'nm60249032'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.23,
#    'place': '7km S of Apison, Tennessee',
#    'time': 1559518967340,
#    'updated': 1560191219320,
#    'tz': -300,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/se60249012',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=se60249012&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 77,
#    'net': 'se',
#    'code': '60249012',
#    'ids': ',se60249012,',
#    'sources': ',se,',
#    'types': ',geoserve,origin,phase-data,',
#    'nst': 11,
#    'dmin': 0.3026,
#    'rms': 0.11,
#    'gap': 60,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.2 - 7km S of Apison, Tennessee'},
#   'geometry': {'type': 'Point', 'coordinates': [-85.0215, 34.9531667, 5.18]},
#   'id': 'se60249012'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.05,
#    'place': '5km NNW of Ridgely, Tennessee',
#    'time': 1559516759930,
#    'updated': 1562071541490,
#    'tz': -360,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60248997',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60248997&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 17,
#    'net': 'nm',
#    'code': '60248997',
#    'ids': ',nm60248997,',
#    'sources': ',nm,',
#    'types': ',geoserve,origin,phase-data,',
#    'nst': 7,
#    'dmin': 0.04452,
#    'rms': 0.17,
#    'gap': 114,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.1 - 5km NNW of Ridgely, Tennessee'},
#   'geometry': {'type': 'Point', 'coordinates': [-89.5168333, 36.305, 6.13]},
#   'id': 'nm60248997'},
#  ...]

# %%
usgs_data = pd.json_normalize(usgs_json,  'features', sep = '_')

# %%
usgs_data.head(20)
# Out:
#        type          id  properties_mag  \
# 0   Feature  nm60116023            2.60
# 1   Feature  nm60313377            1.64
# 2   Feature  nm60115923            2.54
# 3   Feature  se60313352            1.03
# 4   Feature  se60313342           -0.67
# 5   Feature  se60313307           -0.40
# 6   Feature  se60313277           -0.43
# 7   Feature  nm60313272            1.54
# 8   Feature  nm60115823            2.53
# 9   Feature  nm60313127            2.03
# 10  Feature  nm60115723            2.44
# 11  Feature  nm60313122            1.86
# 12  Feature  nm60313112            2.57
# 13  Feature  nm60115728            2.42
# 14  Feature  se60313102            2.45
# 15  Feature  se60313097            1.48
# 16  Feature  se60313092            0.72
# 17  Feature  se60313082            2.81
# 18  Feature  nm60312902            1.65
# 19  Feature  nm60312762            2.14
#
#                          properties_place  properties_time  \
# 0            5 km NE of Maynard, Arkansas    1603916578700
# 1     10 km NNW of Tiptonville, Tennessee    1603895782690
# 2            4 km NE of Maynard, Arkansas    1603879887320
# 3      0 km SSW of Sparta, North Carolina    1603852792520
# 4       3 km SE of Sparta, North Carolina    1603829850670
# 5      3 km ENE of Sparta, North Carolina    1603817138080
# 6       7 km NE of Sparta, North Carolina    1603794929420
# 7         10 km N of Dyersburg, Tennessee    1603779924260
# 8           5 km ENE of Maynard, Arkansas    1603756938930
# 9            6 km E of Ridgely, Tennessee    1603701334140
# 10            6 km E of Maynard, Arkansas    1603698405230
# 11         6 km ENE of Garland, Tennessee    1603685291800
# 12          6 km ENE of Maynard, Arkansas    1603670823060
# 13          6 km ENE of Maynard, Arkansas    1603653013970
# 14      11 km SSW of Maryville, Tennessee    1603646337880
# 15  Virginia-North Carolina border region    1603599003240
# 16     2 km ENE of Sparta, North Carolina    1603597751720
# 17     3 km ENE of Sparta, North Carolina    1603595312000
# 18     5 km SSW of Tiptonville, Tennessee    1603426158260
# 19           2 km NNE of Cooter, Missouri    1603316985720
#
#     properties_updated  properties_tz  \
# 0        1603926441980            NaN
# 1        1603906640460            NaN
# 2        1603893061860            NaN
# 3        1603894032960            NaN
# 4        1603894754730            NaN
# 5        1603895024340            NaN
# 6        1603820655300            NaN
# 7        1603896667500            NaN
# 8        1603801565010            NaN
# 9        1603720788800            NaN
# 10       1603725370010            NaN
# 11       1603724313790            NaN
# 12       1603718153470            NaN
# 13       1603726835050            NaN
# 14       1603813016862            NaN
# 15       1603733531890            NaN
# 16       1603632434150            NaN
# 17       1603864133004            NaN
# 18       1603471929410            NaN
# 19       1603370993160            NaN
#
#                                        properties_url  \
# 0   https://earthquake.usgs.gov/earthquakes/eventp...
# 1   https://earthquake.usgs.gov/earthquakes/eventp...
# 2   https://earthquake.usgs.gov/earthquakes/eventp...
# 3   https://earthquake.usgs.gov/earthquakes/eventp...
# 4   https://earthquake.usgs.gov/earthquakes/eventp...
# 5   https://earthquake.usgs.gov/earthquakes/eventp...
# 6   https://earthquake.usgs.gov/earthquakes/eventp...
# 7   https://earthquake.usgs.gov/earthquakes/eventp...
# 8   https://earthquake.usgs.gov/earthquakes/eventp...
# 9   https://earthquake.usgs.gov/earthquakes/eventp...
# 10  https://earthquake.usgs.gov/earthquakes/eventp...
# 11  https://earthquake.usgs.gov/earthquakes/eventp...
# 12  https://earthquake.usgs.gov/earthquakes/eventp...
# 13  https://earthquake.usgs.gov/earthquakes/eventp...
# 14  https://earthquake.usgs.gov/earthquakes/eventp...
# 15  https://earthquake.usgs.gov/earthquakes/eventp...
# 16  https://earthquake.usgs.gov/earthquakes/eventp...
# 17  https://earthquake.usgs.gov/earthquakes/eventp...
# 18  https://earthquake.usgs.gov/earthquakes/eventp...
# 19  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                     properties_detail  properties_felt  ...  \
# 0   https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 1   https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 2   https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 3   https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 4   https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 5   https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 6   https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 7   https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 8   https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 9   https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 10  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 11  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 12  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 13  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 14  https://earthquake.usgs.gov/fdsnws/event/1/que...              5.0  ...
# 15  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 16  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 17  https://earthquake.usgs.gov/fdsnws/event/1/que...            389.0  ...
# 18  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 19  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
#
#             properties_types  properties_nst properties_dmin properties_rms  \
# 0        ,origin,phase-data,             9.0        0.456400           0.14
# 1        ,origin,phase-data,            29.0        0.066860           0.03
# 2        ,origin,phase-data,             9.0        0.448800           0.03
# 3        ,origin,phase-data,             6.0        0.031760           0.13
# 4        ,origin,phase-data,             4.0        0.005155           0.04
# 5        ,origin,phase-data,             4.0        0.014490           0.07
# 6        ,origin,phase-data,             5.0        0.045570           0.33
# 7        ,origin,phase-data,            12.0        0.035290           0.08
# 8        ,origin,phase-data,            11.0        0.446800           0.25
# 9        ,origin,phase-data,            25.0        0.023040           0.09
# 10       ,origin,phase-data,            16.0        0.443300           0.18
# 11       ,origin,phase-data,            10.0        0.141300           0.28
# 12       ,origin,phase-data,            27.0        0.447600           0.16
# 13       ,origin,phase-data,            20.0        0.447300           0.23
# 14  ,dyfi,origin,phase-data,            23.0        0.140500           0.18
# 15       ,origin,phase-data,             6.0        0.005688           0.21
# 16       ,origin,phase-data,             7.0        0.016140           0.25
# 17  ,dyfi,origin,phase-data,            31.0        0.012590           0.11
# 18       ,origin,phase-data,            24.0        0.018570           0.03
# 19       ,origin,phase-data,            46.0        0.064300           0.10
#
#     properties_gap  properties_magType properties_type  \
# 0            140.0                  md      earthquake
# 1             84.0                  md      earthquake
# 2            141.0                  md      earthquake
# 3            206.0                  md      earthquake
# 4            141.0                  md      earthquake
# 5            284.0                  md      earthquake
# 6            309.0                  md      earthquake
# 7            107.0                  md      earthquake
# 8            136.0                  md      earthquake
# 9             60.0                  md      earthquake
# 10            92.0                  md      earthquake
# 11           233.0                  md      earthquake
# 12            69.0                  md      earthquake
# 13            69.0                  md      earthquake
# 14            80.0                  md      earthquake
# 15           263.0                  md      earthquake
# 16           225.0                  md      earthquake
# 17            70.0                  md      earthquake
# 18            47.0                  md      earthquake
# 19            40.0                  md      earthquake
#
#                                  properties_title geometry_type  \
# 0            M 2.6 - 5 km NE of Maynard, Arkansas         Point
# 1     M 1.6 - 10 km NNW of Tiptonville, Tennessee         Point
# 2            M 2.5 - 4 km NE of Maynard, Arkansas         Point
# 3      M 1.0 - 0 km SSW of Sparta, North Carolina         Point
# 4      M -0.7 - 3 km SE of Sparta, North Carolina         Point
# 5     M -0.4 - 3 km ENE of Sparta, North Carolina         Point
# 6      M -0.4 - 7 km NE of Sparta, North Carolina         Point
# 7         M 1.5 - 10 km N of Dyersburg, Tennessee         Point
# 8           M 2.5 - 5 km ENE of Maynard, Arkansas         Point
# 9            M 2.0 - 6 km E of Ridgely, Tennessee         Point
# 10            M 2.4 - 6 km E of Maynard, Arkansas         Point
# 11         M 1.9 - 6 km ENE of Garland, Tennessee         Point
# 12          M 2.6 - 6 km ENE of Maynard, Arkansas         Point
# 13          M 2.4 - 6 km ENE of Maynard, Arkansas         Point
# 14      M 2.5 - 11 km SSW of Maryville, Tennessee         Point
# 15  M 1.5 - Virginia-North Carolina border region         Point
# 16     M 0.7 - 2 km ENE of Sparta, North Carolina         Point
# 17     M 2.8 - 3 km ENE of Sparta, North Carolina         Point
# 18     M 1.7 - 5 km SSW of Tiptonville, Tennessee         Point
# 19           M 2.1 - 2 km NNE of Cooter, Missouri         Point
#
#                 geometry_coordinates
# 0            [-90.857, 36.459, 3.69]
# 1        [-89.5168333, 36.464, 7.38]
# 2    [-90.8643333, 36.4536667, 3.42]
# 3         [-81.124, 36.4998333, 0.2]
# 4       [-81.0921667, 36.4835, 1.12]
# 5     [-81.0891667, 36.5161667, 0.2]
# 6    [-81.0506667, 36.5438333, 0.16]
# 7    [-89.3751667, 36.1253333, 8.54]
# 8       [-90.8415, 36.4393333, 7.92]
# 9       [-89.4175, 36.2531667, 6.88]
# 10    [-90.8248333, 36.4253333, 9.1]
# 11   [-89.6906667, 35.6151667, 1.51]
# 12       [-90.829, 36.4331667, 11.8]
# 13  [-90.8271667, 36.4316667, 15.36]
# 14  [-84.0246667, 35.6668333, 18.54]
# 15   [-81.0851667, 36.5016667, 1.16]
# 16       [-81.0926667, 36.516, 0.09]
# 17      [-81.0826667, 36.5165, 1.42]
# 18   [-89.4846667, 36.3328333, 4.93]
# 19      [-89.8023333, 36.0705, 6.84]
#
# [20 rows x 30 columns]

# %%
usgs_data.tail(60)
# Out:
#           type          id  properties_mag  \
# 10708  Feature    nm600008            1.60
# 10709  Feature    nm600007            1.60
# 10710  Feature    nm600006            2.00
# 10711  Feature    nm600005            1.40
# 10712  Feature    nm600004            1.90
# 10713  Feature    nm600003            2.50
# 10714  Feature    nm600002            1.80
# 10715  Feature    nm600001            1.60
# 10716  Feature  usp00006jz            3.60
# 10717  Feature  usp00006b7            4.30
# 10718  Feature  usp00005kq            3.20
# 10719  Feature  usp00005jt            2.50
# 10720  Feature  usp00005gp            3.00
# 10721  Feature  usp00005d2            3.20
# 10722  Feature  usp00004v5            4.10
# 10723  Feature  usp00004kc            3.40
# 10724  Feature  usp00004c7            4.70
# 10725  Feature  usp0000406            3.40
# 10726  Feature  usp00003s8            3.80
# 10727  Feature  usp00003nk            3.40
# 10728  Feature  usp000002f            3.20
# 10729  Feature   ushis3164            3.70
# 10730  Feature   ushis3120            4.01
# 10731  Feature   ushis2970            4.04
# 10732  Feature   ushis2838            3.45
# 10733  Feature   ushis2595            4.66
# 10734  Feature   ushis2559            3.39
# 10735  Feature   ushis2536            4.23
# 10736  Feature   ushis2418            3.90
# 10737  Feature   ushis2395            3.80
# 10738  Feature   ushis2369            3.90
# 10739  Feature   ushis2273            3.90
# 10740  Feature   ushis2246            3.70
# 10741  Feature   ushis2232            4.00
# 10742  Feature   ushis2111            4.30
# 10743  Feature   ushis2101            4.10
# 10744  Feature   ushis2079            4.00
# 10745  Feature   ushis2025            3.90
# 10746  Feature   ushis2012            4.40
# 10747  Feature   ushis1908            4.30
# 10748  Feature   ushis1786             NaN
# 10749  Feature   ushis1210            4.80
# 10750  Feature   ushis1077            4.70
# 10751  Feature    ushis794            4.50
# 10752  Feature    ushis763            4.80
# 10753  Feature    ushis743             NaN
# 10754  Feature    ushis700            4.50
# 10755  Feature    ushis695            4.80
# 10756  Feature    ushis678            4.60
# 10757  Feature    ushis677            4.80
# 10758  Feature    ushis641            4.50
# 10759  Feature    ushis606            3.80
# 10760  Feature    ushis587            5.20
# 10761  Feature    ushis580            4.50
# 10762  Feature    ushis545            4.10
# 10763  Feature    ushis544            4.80
# 10764  Feature    ushis494            4.50
# 10726       1415316080747            NaN
# 10727       1415316080614            NaN
# 10728       1415316067438            NaN
# 10729       1528145025000            NaN
# 10730       1528145025000            NaN
# 10731       1528145025000            NaN
# 10732       1587071987293            NaN
# 10733       1528145025000            NaN
# 10734       1528145025000            NaN
# 10735       1528145025000            NaN
# 10736       1528145025000            NaN
# 10737       1528145025000            NaN
# 10738       1528145025000            NaN
# 10739       1528145024000            NaN
# 10740       1528145024000            NaN
# 10741       1528145024000            NaN
# 10742       1528145024000            NaN
# 10743       1528145024000            NaN
# 10744       1528145024000            NaN
# 10745       1528145024000            NaN
# 10746       1528145024000            NaN
# 10747       1528145024000            NaN
# 10748       1528145024000            NaN
# 10749       1528145024000            NaN
# 10750       1528145024000            NaN
# 10751       1528145024000            NaN
# 10752       1528145024000            NaN
# 10753       1528145024000            NaN
# 10754       1528145024000            NaN
# 10755       1528145024000            NaN
# 10756       1528145024000            NaN
# 10757       1528145024000            NaN
# 10758       1528145024000            NaN
# 10759       1528145024000            NaN
# 10760       1528145024000            NaN
# 10761       1528145024000            NaN
# 10762       1528145024000            NaN
# 10763       1528145024000            NaN
# 10764       1528145024000            NaN
# 10765       1528145024000            NaN
# 10766       1528145024000            NaN
# 10767       1528145024000            NaN
#
#                                           properties_url  \
# 10708  https://earthquake.usgs.gov/earthquakes/eventp...
# 10709  https://earthquake.usgs.gov/earthquakes/eventp...
# 10710  https://earthquake.usgs.gov/earthquakes/eventp...
# 10711  https://earthquake.usgs.gov/earthquakes/eventp...
# 10712  https://earthquake.usgs.gov/earthquakes/eventp...
# 10713  https://earthquake.usgs.gov/earthquakes/eventp...
# 10714  https://earthquake.usgs.gov/earthquakes/eventp...
# 10715  https://earthquake.usgs.gov/earthquakes/eventp...
# 10716  https://earthquake.usgs.gov/earthquakes/eventp...
# 10717  https://earthquake.usgs.gov/earthquakes/eventp...
# 10718  https://earthquake.usgs.gov/earthquakes/eventp...
# 10719  https://earthquake.usgs.gov/earthquakes/eventp...
# 10720  https://earthquake.usgs.gov/earthquakes/eventp...
# 10721  https://earthquake.usgs.gov/earthquakes/eventp...
# 10722  https://earthquake.usgs.gov/earthquakes/eventp...
# 10723  https://earthquake.usgs.gov/earthquakes/eventp...
# 10724  https://earthquake.usgs.gov/earthquakes/eventp...
# 10725  https://earthquake.usgs.gov/earthquakes/eventp...
# 10726  https://earthquake.usgs.gov/earthquakes/eventp...
# 10727  https://earthquake.usgs.gov/earthquakes/eventp...
# 10728  https://earthquake.usgs.gov/earthquakes/eventp...
# 10729  https://earthquake.usgs.gov/earthquakes/eventp...
# 10730  https://earthquake.usgs.gov/earthquakes/eventp...
# 10731  https://earthquake.usgs.gov/earthquakes/eventp...
# 10732  https://earthquake.usgs.gov/earthquakes/eventp...
# 10733  https://earthquake.usgs.gov/earthquakes/eventp...
# 10734  https://earthquake.usgs.gov/earthquakes/eventp...
# 10735  https://earthquake.usgs.gov/earthquakes/eventp...
# 10736  https://earthquake.usgs.gov/earthquakes/eventp...
# 10737  https://earthquake.usgs.gov/earthquakes/eventp...
# 10738  https://earthquake.usgs.gov/earthquakes/eventp...
# 10739  https://earthquake.usgs.gov/earthquakes/eventp...
# 10740  https://earthquake.usgs.gov/earthquakes/eventp...
# 10741  https://earthquake.usgs.gov/earthquakes/eventp...
# 10742  https://earthquake.usgs.gov/earthquakes/eventp...
# 10743  https://earthquake.usgs.gov/earthquakes/eventp...
# 10744  https://earthquake.usgs.gov/earthquakes/eventp...
# 10745  https://earthquake.usgs.gov/earthquakes/eventp...
# 10746  https://earthquake.usgs.gov/earthquakes/eventp...
# 10747  https://earthquake.usgs.gov/earthquakes/eventp...
# 10748  https://earthquake.usgs.gov/earthquakes/eventp...
# 10749  https://earthquake.usgs.gov/earthquakes/eventp...
# 10750  https://earthquake.usgs.gov/earthquakes/eventp...
# 10751  https://earthquake.usgs.gov/earthquakes/eventp...
# 10752  https://earthquake.usgs.gov/earthquakes/eventp...
# 10753  https://earthquake.usgs.gov/earthquakes/eventp...
# 10754  https://earthquake.usgs.gov/earthquakes/eventp...
# 10755  https://earthquake.usgs.gov/earthquakes/eventp...
# 10756  https://earthquake.usgs.gov/earthquakes/eventp...
# 10757  https://earthquake.usgs.gov/earthquakes/eventp...
# 10758  https://earthquake.usgs.gov/earthquakes/eventp...
# 10759  https://earthquake.usgs.gov/earthquakes/eventp...
# 10760  https://earthquake.usgs.gov/earthquakes/eventp...
# 10761  https://earthquake.usgs.gov/earthquakes/eventp...
# 10762  https://earthquake.usgs.gov/earthquakes/eventp...
# 10763  https://earthquake.usgs.gov/earthquakes/eventp...
# 10764  https://earthquake.usgs.gov/earthquakes/eventp...
# 10765  https://earthquake.usgs.gov/earthquakes/eventp...
# 10766  https://earthquake.usgs.gov/earthquakes/eventp...
# 10767  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                        properties_detail  properties_felt  \
# 10708  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10709  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10710  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10711  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10712  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10713  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10714  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10715  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10716  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10717  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10718  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10719  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10720  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10721  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10722  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10723  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10724  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10725  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10726  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10727  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10728  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10729  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10730  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10731  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10732  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10733  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10734  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10735  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10736  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10737  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10738  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10739  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10740  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10741  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10742  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10743  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10744  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10745  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10746  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10747  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10748  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10749  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10750  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10751  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10752  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10753  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10754  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10755  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10756  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10757  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10758  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10759  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10760  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10761  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10762  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10763  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10764  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10765  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10766  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
# 10767  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN
#
#        ...                                   properties_types  properties_nst  \
# 10708  ...  ,general-link,geoserve,nearby-cities,origin,te...             NaN
# 10709  ...  ,general-link,general-link,geoserve,nearby-cit...             NaN
# 10710  ...  ,general-link,geoserve,nearby-cities,origin,te...             NaN
# 10711  ...  ,general-link,geoserve,nearby-cities,origin,te...             NaN
# 10712  ...  ,general-link,geoserve,nearby-cities,origin,te...             NaN
# 10713  ...  ,general-link,geoserve,nearby-cities,origin,te...             NaN
# 10714  ...  ,general-link,geoserve,nearby-cities,origin,te...             NaN
# 10715  ...  ,general-link,geoserve,nearby-cities,origin,te...             NaN
# 10716  ...                                           ,origin,             NaN
# 10717  ...                      ,impact-text,origin,shakemap,             NaN
# 10718  ...                                           ,origin,             NaN
# 10719  ...                                           ,origin,             NaN
# 10720  ...                                           ,origin,             NaN
# 10721  ...                                           ,origin,             NaN
# 10722  ...                                           ,origin,             NaN
# 10723  ...                                           ,origin,             NaN
# 10724  ...  ,impact-text,origin,shakemap,touch,trump-shake...             NaN
# 10725  ...                                           ,origin,             NaN
# 10726  ...                                           ,origin,             NaN
# 10727  ...                                           ,origin,             NaN
# 10728  ...                                           ,origin,             NaN
# 10729  ...                               ,impact-text,origin,             NaN
# 10730  ...                               ,impact-text,origin,             NaN
# 10731  ...                               ,impact-text,origin,             NaN
# 10732  ...                      ,impact-text,origin,shakemap,             NaN
# 10733  ...                               ,impact-text,origin,             NaN
# 10734  ...                               ,impact-text,origin,             NaN
# 10735  ...                               ,impact-text,origin,             NaN
# 10736  ...                               ,impact-text,origin,             NaN
# 10737  ...                               ,impact-text,origin,             NaN
# 10738  ...                               ,impact-text,origin,             NaN
# 10739  ...                               ,impact-text,origin,             NaN
# 10740  ...                               ,impact-text,origin,             NaN
# 10741  ...                               ,impact-text,origin,             NaN
# 10742  ...                               ,impact-text,origin,             NaN
# 10743  ...                               ,impact-text,origin,             NaN
# 10744  ...                               ,impact-text,origin,             NaN
# 10745  ...                               ,impact-text,origin,             NaN
# 10746  ...                               ,impact-text,origin,             NaN
# 10747  ...                               ,impact-text,origin,             NaN
# 10748  ...                               ,impact-text,origin,             NaN
# 10749  ...                               ,impact-text,origin,             NaN
# 10750  ...                               ,impact-text,origin,             NaN
# 10751  ...                               ,impact-text,origin,             NaN
# 10752  ...                               ,impact-text,origin,             NaN
# 10753  ...                               ,impact-text,origin,             NaN
# 10754  ...                               ,impact-text,origin,             NaN
# 10755  ...                               ,impact-text,origin,             NaN
# 10756  ...                               ,impact-text,origin,             NaN
# 10757  ...                               ,impact-text,origin,             NaN
# 10758  ...                               ,impact-text,origin,             NaN
# 10759  ...                               ,impact-text,origin,             NaN
# 10760  ...                               ,impact-text,origin,             NaN
# 10761  ...                               ,impact-text,origin,             NaN
# 10762  ...                               ,impact-text,origin,             NaN
# 10763  ...                               ,impact-text,origin,             NaN
# 10764  ...                               ,impact-text,origin,             NaN
# 10765  ...                               ,impact-text,origin,             NaN
# 10766  ...                               ,impact-text,origin,             NaN
# 10767  ...                               ,impact-text,origin,             NaN
#
#       properties_dmin properties_rms  properties_gap  properties_magType  \
# 10708             NaN            NaN             NaN                 mlg
# 10709             NaN            NaN             NaN                 mlg
# 10710             NaN            NaN             NaN                 mlg
# 10711             NaN            NaN             NaN                 mlg
# 10712             NaN            NaN             NaN                 mlg
# 10713             NaN            NaN             NaN                 mlg
# 10714             NaN            NaN             NaN                 mlg
# 10715             NaN            NaN             NaN                 mlg
# 10716             NaN            NaN             NaN                  lg
# 10717             NaN            NaN             NaN                  mb
# 10718             NaN            NaN             NaN                  lg
# 10719             NaN            NaN             NaN                  lg
# 10720             NaN            NaN             NaN                  lg
# 10721             NaN            NaN             NaN                  lg
# 10722             NaN            NaN             NaN                  mb
# 10723             NaN            NaN             NaN                  lg
# 10724             NaN            NaN             NaN                  mb
# 10725             NaN            NaN             NaN                  lg
# 10726             NaN            NaN             NaN                  lg
# 10727             NaN            NaN             NaN                  lg
# 10728             NaN            NaN             NaN                  lg
# 10729             NaN            NaN             NaN                  lg
# 10730             NaN            NaN             NaN                  mw
# 10731             NaN            NaN             NaN                  mw
# 10732             NaN            NaN             NaN                  mw
# 10733             NaN            NaN             NaN                  mw
# 10734             NaN            NaN             NaN                  mw
# 10735             NaN            NaN             NaN                  mw
# 10736             NaN            NaN             NaN                  fa
# 10737             NaN            NaN             NaN                  fa
# 10738             NaN            NaN             NaN                  fa
# 10739             NaN            NaN             NaN                  fa
# 10740             NaN            NaN             NaN                  fa
# 10741             NaN            NaN             NaN                  fa
# 10742             NaN            NaN             NaN                  fa
# 10743             NaN            NaN             NaN                  fa
# 10744             NaN            NaN             NaN                  fa
# 10745             NaN            NaN             NaN                  fa
# 10746             NaN            NaN             NaN                  fa
# 10747             NaN            NaN             NaN                  fa
# 10748             NaN            NaN             NaN                None
# 10749             NaN            NaN             NaN                  fa
# 10750             NaN            NaN             NaN                  fa
# 10751             NaN            NaN             NaN                  lg
# 10752             NaN            NaN             NaN                  fa
# 10753             NaN            NaN             NaN                None
# 10754             NaN            NaN             NaN                  fa
# 10755             NaN            NaN             NaN                  fa
# 10756             NaN            NaN             NaN                  fa
# 10757             NaN            NaN             NaN                  fa
# 10758             NaN            NaN             NaN                  fa
# 10759             NaN            NaN             NaN                  fa
# 10760             NaN            NaN             NaN                  fa
# 10761             NaN            NaN             NaN                  fa
# 10762             NaN            NaN             NaN                  fa
# 10763             NaN            NaN             NaN                  fa
# 10764             NaN            NaN             NaN                  fa
# 10765             NaN            NaN             NaN                  fa
# 10766             NaN            NaN             NaN                  fa
# 10767             NaN            NaN             NaN                  fa
#
#       properties_type                                properties_title  \
# 10708      earthquake          M 1.6 - 12km ESE of Ridgely, Tennessee
# 10709      earthquake             M 1.6 - 9km NE of Gosnell, Arkansas
# 10710      earthquake       M 2.0 - 4km WNW of East Prairie, Missouri
# 10711      earthquake            M 1.4 - 8km SW of Lilbourn, Missouri
# 10712      earthquake           M 1.9 - 10km NNW of Clinton, Kentucky
# 10713      earthquake             M 2.5 - 7km S of Bardwell, Kentucky
# 10714      earthquake            M 1.8 - 2km SW of Ridgely, Tennessee
# 10715      earthquake             M 1.6 - 10km WNW of Troy, Tennessee
# 10716      earthquake                           M 3.6 - West Virginia
# 10717      earthquake                                M 4.3 - Missouri
# 10718      earthquake                               M 3.2 - Tennessee
# 10719      earthquake                               M 2.5 - Tennessee
# 10720      earthquake                                M 3.0 - Arkansas
# 10721      earthquake                                M 3.2 - Arkansas
# 10722      earthquake                               M 4.1 - Tennessee
# 10723      earthquake                               M 3.4 - Tennessee
# 10724      earthquake                       M 4.7 - eastern Tennessee
# 10725      earthquake                       M 3.4 - eastern Tennessee
# 10726      earthquake                                M 3.8 - Missouri
# 10727      earthquake                                M 3.4 - Arkansas
# 10728      earthquake                        M 3.2 - western Kentucky
# 10729      earthquake                          M 3.7 - South Carolina
# 10730      earthquake                                M 4.0 - Arkansas
# 10731      earthquake                                M 4.0 - Missouri
# 10732      earthquake                                M 3.5 - Illinois
# 10733      earthquake                                M 4.7 - Missouri
# 10734      earthquake                               M 3.4 - Tennessee
# 10735      earthquake                               M 4.2 - Tennessee
# 10736      earthquake                          M 3.9 - South Carolina
# 10737      earthquake                                 M 3.8 - Alabama
# 10738      earthquake                           M 3.9 - West Virginia
# 10739      earthquake  M 3.9 - Tennessee-North Carolina border region
# 10740      earthquake                          M 3.7 - North Carolina
# 10741      earthquake                          M 4.0 - North Carolina
# 10742      earthquake                                M 4.3 - Missouri
# 10743      earthquake                       M 4.1 - eastern Tennessee
# 10744      earthquake                               M 4.0 - Tennessee
# 10745      earthquake                               M 3.9 - Tennessee
# 10746      earthquake                                M 4.4 - Missouri
# 10747      earthquake                        M 4.3 - eastern Kentucky
# 10748      earthquake                                 M ? - Tennessee
# 10749      earthquake                                M 4.8 - Arkansas
# 10750      earthquake                                M 4.7 - Missouri
# 10751      earthquake                       M 4.5 - eastern Tennessee
# 10752      earthquake                                M 4.8 - Arkansas
# 10753      earthquake                            M ? - North Carolina
# 10754      earthquake                                M 4.5 - Arkansas
# 10755      earthquake                                M 4.8 - Arkansas
# 10756      earthquake                                M 4.6 - Illinois
# 10757      earthquake                                M 4.8 - Illinois
# 10758      earthquake                               M 4.5 - Tennessee
# 10759      earthquake                                M 3.8 - Missouri
# 10760      earthquake                          M 5.2 - North Carolina
# 10761      earthquake                                M 4.5 - Arkansas
# 10762      earthquake                       M 4.1 - eastern Tennessee
# 10763      earthquake                          M 4.8 - South Carolina
# 10764      earthquake                                M 4.5 - Missouri
# 10765      earthquake                                M 4.8 - Illinois
# 10766      earthquake                                M 5.1 - Missouri
# 10767      earthquake                               M 4.6 - Tennessee
#
#       geometry_type   geometry_coordinates
# 10708         Point     [-89.35, 36.23, 5]
# 10709         Point      [-89.9, 36.02, 5]
# 10710         Point      [-89.43, 36.8, 5]
# 10711         Point     [-89.69, 36.54, 5]
# 10712         Point     [-89.06, 36.75, 5]
# 10713         Point      [-89.01, 36.8, 5]
# 10714         Point     [-89.51, 36.25, 5]
# 10715         Point     [-89.28, 36.36, 5]
# 10716         Point   [-80.419, 37.382, 8]
# 10717         Point     [-89.39, 36.71, 1]
# 10718         Point     [-89.79, 35.66, 5]
# 10719         Point     [-89.53, 36.21, 5]
# 10720         Point     [-90.35, 35.68, 5]
# 10721         Point     [-90.38, 35.82, 6]
# 10722         Point      [-89.39, 36.2, 1]
# 10723         Point   [-89.58, 36.157, 10]
# 10724         Point   [-83.962, 35.799, 3]
# 10725         Point       [-84, 35.75, 33]
# 10726         Point     [-89.61, 36.51, 1]
# 10727         Point       [-90, 35.91, 10]
# 10728         Point     [-87.3, 37.44, 15]
# 10729         Point  [-82.98, 34.76, None]
# 10730         Point  [-89.947, 35.856, 14]
# 10731         Point   [-90.443, 37.44, 12]
# 10732         Point   [-89.307, 37.226, 1]
# 10733         Point    [-90.05, 36.642, 9]
# 10734         Point   [-89.399, 36.044, 8]
# 10735         Point   [-89.511, 36.374, 4]
# 10736         Point    [-80.2, 34.5, None]
# 10737         Point   [-86.562, 34.789, 5]
# 10738         Point   [-80.682, 37.395, 1]
# 10739         Point      [-83.5, 35, None]
# 10740         Point       [-82.7, 35.6, 7]
# 10741         Point   [-82.142, 35.799, 5]
# 10742         Point   [-90.387, 36.914, 1]
# 10743         Point   [-83.787, 36.445, 5]
# 10744         Point  [-89.803, 35.756, 16]
# 10745         Point      [-89.5, 36, None]
# 10746         Point   [-89.827, 36.073, 8]
# 10747         Point    [-83.7, 36.6, None]
# 10748         Point    [-89.6, 36.2, None]
# 10749         Point   [-90.254, 35.413, 1]
# 10750         Point   [-89.2, 36.95, None]
# 10751         Point   [-82.828, 36.112, 5]
# 10752         Point    [-90.4, 35.8, None]
# 10753         Point    [-82.1, 35.9, None]
# 10754         Point        [-90, 36, None]
# 10755         Point    [-90.4, 35.5, None]
# 10756         Point    [-89.4, 37.4, None]
# 10757         Point    [-89.4, 37.4, None]
# 10758         Point      [-89.2, 36, None]
# 10759         Point    [-89.2, 36.6, None]
# 10760         Point    [-82.5, 35.5, None]
# 10761         Point        [-90, 36, None]
# 10762         Point    [-83.7, 36.2, None]
# 10763         Point    [-81.7, 34.7, None]
# 10764         Point      [-89.5, 37, None]
# 10765         Point    [-89.3, 37.2, None]
# 10766         Point    [-89.8, 36.5, None]
# 10767         Point    [-89.5, 36.5, None]
#
# [60 rows x 30 columns]

# %%
usgs_data.columns = [col.replace('properties_', '') for col in usgs_data.columns]
usgs_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10768 entries, 0 to 10767
# Data columns (total 30 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  10768 non-null  object
#  1   id                    10768 non-null  object
#  2   mag                   10761 non-null  float64
#  3   place                 10768 non-null  object
#  4   time                  10768 non-null  int64
#  5   updated               10768 non-null  int64
#  6   tz                    10151 non-null  float64
#  7   url                   10768 non-null  object
#  8   detail                10768 non-null  object
#  9   felt                  856 non-null    float64
#  10  cdi                   856 non-null    float64
#  11  mmi                   65 non-null     float64
#  12  alert                 22 non-null     object
#  13  status                10768 non-null  object
#  14  tsunami               10768 non-null  int64
#  15  sig                   10768 non-null  int64
#  16  net                   10768 non-null  object
#  17  code                  10768 non-null  object
#  18  ids                   10768 non-null  object
#  19  sources               10768 non-null  object
#  20  types                 10768 non-null  object
#  21  nst                   7076 non-null   float64
#  22  dmin                  6792 non-null   float64
#  23  rms                   7087 non-null   float64
#  24  gap                   7071 non-null   float64
#  25  magType               10747 non-null  object
#  26  type                  10768 non-null  object
#  27  title                 10768 non-null  object
#  28  geometry_type         10768 non-null  object
#  29  geometry_coordinates  10768 non-null  object
# dtypes: float64(9), int64(4), object(17)
# memory usage: 2.5+ MB

# %%
usgs_data['title'].unique()
# Out:
# array(['M 2.6 - 5 km NE of Maynard, Arkansas',
#        'M 1.6 - 10 km NNW of Tiptonville, Tennessee',
#        'M 2.5 - 4 km NE of Maynard, Arkansas', ..., 'M 4.5 - Missouri',
#        'M 5.1 - Missouri', 'M 4.6 - Tennessee'], dtype=object)

# %%
#usgs_data.columns = usgs_data.columns.str.strip('properties.')
#usgs_data.columns = usgs_data.columns.str.lstrip('\properties.')

# %%
usgs_data['TN'] = usgs_data['place'].str.contains('Tennessee')

# %%
usgs_tn= usgs_data[usgs_data['TN']==True]

# %%
usgs_tn.query('mag>=2.5', inplace=True)
usgs_tn.shape
# Out:
# <ipython-input-14-914b11deb611>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usgs_tn.query('mag>=2.5', inplace=True)
# (324, 31)

# %%
usgs_tn=pd.DataFrame(usgs_tn)
usgs_tn[['longitude', 'latitude', 'depth']] = pd.DataFrame(usgs_tn['geometry_coordinates'].tolist(), index= usgs_tn.index)
usgs_tn.head(60)
# Out:
#          type          id   mag                                place  \
# 403   Feature  se60323696  2.61       7 km ENE of Seymour, Tennessee
# 447   Feature  nm60299502  2.53        1 km SW of Ridgely, Tennessee
# 518   Feature  se60105623  2.78        8km SSE of Sewanee, Tennessee
# 519   Feature  se60316866  3.13        7km SSE of Sewanee, Tennessee
# 531   Feature  se60289532  2.50       4km ENE of Rutledge, Tennessee
# 545   Feature  nm60287482  2.74    3km SSE of Tiptonville, Tennessee
# 550   Feature  nm60286767  2.73        7km ESE of Ridgely, Tennessee
# 629   Feature  se60303036  2.72      4km ENE of Fincastle, Tennessee
# 641   Feature  nm60301761  2.78      9km NNW of Dyersburg, Tennessee
# 656   Feature  se60300191  3.80      3km ENE of Fincastle, Tennessee
# 657   Feature  se60300001  2.75      3km ENE of Fincastle, Tennessee
# 662   Feature  nm60299691  2.53      2km NNW of Dyersburg, Tennessee
# 676   Feature  nm60272917  2.51        3km ENE of Ridgely, Tennessee
# 692   Feature  se60272552  2.52        5km ENE of Decatur, Tennessee
# 806   Feature  nm60291521  2.75         2km NW of Ridgely, Tennessee
# 807   Feature  nm60291511  2.70         2km NW of Ridgely, Tennessee
# 924   Feature  se60259057  2.60         3km SSE of Mascot, Tennessee
# 944   Feature  se60281976  2.95    8km SW of New Tazewell, Tennessee
# 1002  Feature  se60248922  2.55     3km ESE of Manchester, Tennessee
# 1010  Feature  nm60248187  2.74         1km NW of Ridgely, Tennessee
# 1030  Feature  se60271691  2.58         5km SSW of Loudon, Tennessee
# 1039  Feature  se60271191  2.53       8km NW of Coalfield, Tennessee
# 1041  Feature  se60270626  2.57        7km NW of Farragut, Tennessee
# 1053  Feature  nm60268341  3.69     12km NNW of Dyersburg, Tennessee
# 1056  Feature  nm60268121  2.51         4km NW of Ridgely, Tennessee
# 1062  Feature  nm60266676  2.80        4km SSE of Ridgely, Tennessee
# 1063  Feature  nm60266671  2.51        3km SSE of Ridgely, Tennessee
# 1083  Feature  nm60238927  2.59     10km NNW of Dyersburg, Tennessee
# 1122  Feature  se60233907  3.37    7km NE of Maynardville, Tennessee
# 1127  Feature  nm60233077  2.61        6km SSE of Ridgely, Tennessee
# 1152  Feature  se60074023  2.50         3km E of Rutledge, Tennessee
# 1153  Feature  se60254776  2.51         3km E of Rutledge, Tennessee
# 1173  Feature  se60251476  2.77     13km E of Shelbyville, Tennessee
https://earthquake.usgs.gov/fdsnws/event/1/que...      7.0  ...   30.0
#
#       magType        type                                        title  \
# 403        md  earthquake       M 2.6 - 7 km ENE of Seymour, Tennessee
# 447        md  earthquake        M 2.5 - 1 km SW of Ridgely, Tennessee
# 518        md  earthquake        M 2.8 - 8km SSE of Sewanee, Tennessee
# 519        md  earthquake        M 3.1 - 7km SSE of Sewanee, Tennessee
# 531        md  earthquake       M 2.5 - 4km ENE of Rutledge, Tennessee
# 545        md  earthquake    M 2.7 - 3km SSE of Tiptonville, Tennessee
# 550        md  earthquake        M 2.7 - 7km ESE of Ridgely, Tennessee
# 629        md  earthquake      M 2.7 - 4km ENE of Fincastle, Tennessee
# 641        md  earthquake      M 2.8 - 9km NNW of Dyersburg, Tennessee
# 656        mb  earthquake      M 3.8 - 3km ENE of Fincastle, Tennessee
# 657        md  earthquake      M 2.8 - 3km ENE of Fincastle, Tennessee
# 662        md  earthquake      M 2.5 - 2km NNW of Dyersburg, Tennessee
# 676        md  earthquake        M 2.5 - 3km ENE of Ridgely, Tennessee
# 692        md  earthquake        M 2.5 - 5km ENE of Decatur, Tennessee
# 806        md  earthquake         M 2.8 - 2km NW of Ridgely, Tennessee
# 807        md  earthquake         M 2.7 - 2km NW of Ridgely, Tennessee
# 924        md  earthquake         M 2.6 - 3km SSE of Mascot, Tennessee
# 944        md  earthquake    M 3.0 - 8km SW of New Tazewell, Tennessee
# 1002       md  earthquake     M 2.6 - 3km ESE of Manchester, Tennessee
# 1010       md  earthquake         M 2.7 - 1km NW of Ridgely, Tennessee
# 1030       md  earthquake         M 2.6 - 5km SSW of Loudon, Tennessee
# 1039       md  earthquake       M 2.5 - 8km NW of Coalfield, Tennessee
# 1041       md  earthquake        M 2.6 - 7km NW of Farragut, Tennessee
# 1053       mw  earthquake     M 3.7 - 12km NNW of Dyersburg, Tennessee
# 1056       md  earthquake         M 2.5 - 4km NW of Ridgely, Tennessee
# 1062       md  earthquake        M 2.8 - 4km SSE of Ridgely, Tennessee
# 1063       md  earthquake        M 2.5 - 3km SSE of Ridgely, Tennessee
# 1083       md  earthquake     M 2.6 - 10km NNW of Dyersburg, Tennessee
# 1122       md  earthquake    M 3.4 - 7km NE of Maynardville, Tennessee
# 1127       md  earthquake        M 2.6 - 6km SSE of Ridgely, Tennessee
# 1152       md  earthquake         M 2.5 - 3km E of Rutledge, Tennessee
# 1153       md  earthquake         M 2.5 - 3km E of Rutledge, Tennessee
# 1173       md  earthquake     M 2.8 - 13km E of Shelbyville, Tennessee
# 1175       md  earthquake       M 2.7 - 2km NE of Maryville, Tennessee
# 1200       md  earthquake         M 2.8 - 13km SE of Vonore, Tennessee
# 1217       md  earthquake         M 3.0 - 5km ESE of Mascot, Tennessee
# 1220       md  earthquake           M 2.7 - 4km W of Blaine, Tennessee
# 1228       md  earthquake       M 3.0 - 10km NNE of Decatur, Tennessee
# 1229       mw  earthquake       M 4.4 - 12km NNE of Decatur, Tennessee
# 1233       md  earthquake     M 2.7 - 12km NW of Sweetwater, Tennessee
# 1262       md  earthquake     M 2.9 - 9km NW of Tiptonville, Tennessee
# 1264       md  earthquake     M 3.1 - 9km NW of Tiptonville, Tennessee
# 1309       md  earthquake        M 3.3 - 3km ENE of Ridgely, Tennessee
# 1391       md  earthquake     M 2.6 - 10km N of Tiptonville, Tennessee
# 1392       md  earthquake     M 2.7 - 10km N of Tiptonville, Tennessee
# 1430       md  earthquake      M 2.7 - 6km ESE of Englewood, Tennessee
# 1539       md  earthquake       M 2.7 - 11km NNE of Decatur, Tennessee
# 1561       md  earthquake    M 2.7 - 9km NNW of Lenoir City, Tennessee
# 1586       md  earthquake  M 3.1 - 10km WSW of Bean Station, Tennessee
# 1592       md  earthquake          M 2.7 - 5km SW of Mascot, Tennessee
# 1610       md  earthquake           M 2.5 - 8km E of Mascot, Tennessee
# 1740       md  earthquake   M 2.7 - 10km NE of Maynardville, Tennessee
# 1794       md  earthquake       M 2.8 - 9km SSE of Rockwood, Tennessee
# 1843       md  earthquake     M 2.7 - 10km WSW of Knoxville, Tennessee
# 1861       md  earthquake    M 2.9 - 5km WNW of Tiptonville, Tennessee
# 1872       md  earthquake         M 2.5 - 5km SSW of Athens, Tennessee
# 1875       md  earthquake      M 2.7 - 8km N of Sevierville, Tennessee
# 1878       md  earthquake          M 3.1 - 4km N of Ridgely, Tennessee
# 1886       md  earthquake        M 2.7 - 7km N of Greenback, Tennessee
# 1890       md  earthquake    M 2.9 - 11km NW of Tiptonville, Tennessee
#
#       geometry_type              geometry_coordinates    TN  longitude  \
# 403           Point     [-83.6435, 35.9183333, 17.35]  True -83.643500
# 447           Point   [-89.4991667, 36.2566667, 9.43]  True -89.499167
# 518           Point           [-85.883, 35.142, 6.48]  True -85.883000
# 519           Point      [-85.8918333, 35.1405, 8.43]  True -85.891833
# 531           Point     [-83.4638333, 36.3036667, 15]  True -83.463833
# 545           Point       [-89.462, 36.3458333, 5.22]  True -89.462000
# 550           Point      [-89.4008333, 36.2485, 5.79]  True -89.400833
# 629           Point     [-84.0243333, 36.4295, 34.91]  True -84.024333
# 641           Point  [-89.4156667, 36.1051667, 11.74]  True -89.415667
# 656           Point     [-84.0268333, 36.4305, 34.84]  True -84.026833
# 657           Point  [-84.0281667, 36.4308333, 33.89]  True -84.028167
# 662           Point  [-89.4043333, 36.0621667, 11.56]  True -89.404333
# 676           Point   [-89.4698333, 36.2761667, 5.47]  True -89.469833
# 692           Point      [-84.7261667, 35.534, 15.93]  True -84.726167
# 806           Point   [-89.5078333, 36.2756667, 8.06]  True -89.507833
# 807           Point   [-89.5068333, 36.2771667, 8.35]  True -89.506833
# 924           Point         [-83.7395, 36.0385, 7.41]  True -83.739500
# 944           Point  [-83.6471667, 36.3906667, 13.13]  True -83.647167
# 1002          Point   [-86.0421667, 35.4623333, 6.45]  True -86.042167
# 1010          Point   [-89.5021667, 36.2811667, 9.56]  True -89.502167
# 1030          Point  [-84.3668333, 35.6908333, 20.63]  True -84.366833
# 1039          Point  [-84.4768333, 36.0778333, 12.17]  True -84.476833
# 1041          Point  [-84.2191667, 35.9181667, 12.05]  True -84.219167
# 1053          Point  [-89.4398333, 36.1358333, 14.16]  True -89.439833
# 1056          Point   [-89.5228333, 36.2893333, 8.68]  True -89.522833
# 1062          Point       [-89.458, 36.2148333, 9.32]  True -89.458000
# 1063          Point   [-89.4601667, 36.2081667, 8.11]  True -89.460167
# 1083          Point     [-89.4265, 36.1236667, 11.81]  True -89.426500
# 1122          Point     [-83.7356667, 36.2955, 17.07]  True -83.735667
# 1127          Point      [-89.4456667, 36.1885, 8.94]  True -89.445667
# 1152          Point  [-83.4743333, 36.2816667, 10.07]  True -83.474333
# 1153          Point  [-83.4758333, 36.2801667, 11.46]  True -83.475833
# 1173          Point   [-86.3088333, 35.4858333, 6.52]  True -86.308833
# 1175          Point  [-83.9556667, 35.7708333, 13.01]  True -83.955667
# 1200          Point  [-84.1481667, 35.4911667, 19.01]  True -84.148167
# 1217          Point     [-83.6955, 36.0383333, 19.69]  True -83.695500
# 1220          Point   [-83.7523333, 36.1468333, 4.76]  True -83.752333
# 1228          Point          [-84.736, 35.6025, 5.84]  True -84.736000
# 1229          Point       [-84.732, 35.6123333, 7.87]  True -84.732000
# 1233          Point         [-84.564, 35.6795, 21.84]  True -84.564000
# 1262          Point       [-89.5366667, 36.445, 9.54]  True -89.536667
# 1264          Point      [-89.5365, 36.4481667, 9.77]  True -89.536500
# 1309          Point      [-89.4448333, 36.2715, 6.52]  True -89.444833
# 1391          Point       [-89.467, 36.4748333, 4.71]  True -89.467000
# 1392          Point       [-89.4661667, 36.475, 4.82]  True -89.466167
# 1430          Point          [-84.424, 35.397, 18.47]  True -84.424000
# 1539          Point   [-84.7268333, 35.6063333, 4.63]  True -84.726833
# 1561          Point     [-84.2945, 35.8633333, 15.99]  True -84.294500
# 1586          Point     [-83.3895, 36.2968333, 21.17]  True -83.389500
# 1592          Point   [-83.7891667, 36.0261667, 8.24]  True -83.789167
# 1610          Point          [-83.6535, 36.07, 19.82]  True -83.653500
# 1740          Point  [-83.7091667, 36.3186667, 18.63]  True -83.709167
# 1794          Point      [-84.645, 35.7848333, 24.02]  True -84.645000
# 1843          Point  [-84.0301667, 35.9343333, 10.68]  True -84.030167
# 1861          Point    [-89.5301667, 36.3928333, 8.9]  True -89.530167
# 1872          Point  [-84.6248333, 35.4033333, 15.39]  True -84.624833
# 1875          Point      [-83.5611667, 35.945, 10.33]  True -83.561167
# 1878          Point   [-89.4903333, 36.3061667, 4.81]  True -89.490333
# 1886          Point          [-84.165, 35.725, 22.57]  True -84.165000
# 1890          Point  [-89.5701667, 36.4503333, 10.52]  True -89.570167
#
#        latitude  depth
# 403   35.918333  17.35
# 447   36.256667   9.43
# 518   35.142000   6.48
# 519   35.140500   8.43
# 531   36.303667  15.00
# 545   36.345833   5.22
# 550   36.248500   5.79
# 629   36.429500  34.91
# 641   36.105167  11.74
# 656   36.430500  34.84
# 657   36.430833  33.89
# 662   36.062167  11.56
# 676   36.276167   5.47
# 692   35.534000  15.93
# 806   36.275667   8.06
# 807   36.277167   8.35
# 924   36.038500   7.41
# 944   36.390667  13.13
# 1002  35.462333   6.45
# 1010  36.281167   9.56
# 1030  35.690833  20.63
# 1039  36.077833  12.17
# 9613   Feature  usp00018fn  3.30                       eastern Tennessee
# 9636   Feature  usp00016sz  2.60                       eastern Tennessee
# 9691   Feature    nm601116  2.50       5km WSW of Tiptonville, Tennessee
# 9733   Feature  usp00012wr  3.20                       eastern Tennessee
# 9747   Feature  usp00012cz  3.70                       eastern Tennessee
# 9989   Feature    nm600786  3.50         6km NNW of Dyersburg, Tennessee
# 10085  Feature    nm600681  2.60           1km ENE of Ridgely, Tennessee
# 10110  Feature    nm600655  2.60           6km ESE of Ridgely, Tennessee
# 10137  Feature  usp0000r6j  2.80        Tennessee-Virginia border region
# 10143  Feature    nm600621  3.00          12km ESE of Ridgely, Tennessee
# 10163  Feature  usp0000pwm  3.50                       eastern Tennessee
# 10504  Feature    nm600238  2.50             8km S of Ridgely, Tennessee
# 10510  Feature    nm600232  3.30            7km SE of Ridgely, Tennessee
# 10531  Feature  usp0000b1h  2.70                               Tennessee
# 10539  Feature  usp0000aw0  2.60                       eastern Tennessee
# 10718  Feature  usp00005kq  3.20                               Tennessee
# 10719  Feature  usp00005jt  2.50                               Tennessee
# 10722  Feature  usp00004v5  4.10                               Tennessee
# 10723  Feature  usp00004kc  3.40                               Tennessee
# 10724  Feature  usp00004c7  4.70                       eastern Tennessee
# 10725  Feature  usp0000406  3.40                       eastern Tennessee
# 10734  Feature   ushis2559  3.39                               Tennessee
# 10735  Feature   ushis2536  4.23                               Tennessee
# 10739  Feature   ushis2273  3.90  Tennessee-North Carolina border region
# 10743  Feature   ushis2101  4.10                       eastern Tennessee
# 10744  Feature   ushis2079  4.00                               Tennessee
# 10745  Feature   ushis2025  3.90                               Tennessee
# 10751  Feature    ushis794  4.50                       eastern Tennessee
# 10758  Feature    ushis641  4.50                               Tennessee
# 10762  Feature    ushis545  4.10                       eastern Tennessee
# 10767  Feature    ushis422  4.60                               Tennessee
#
#                 time        updated     tz  \
# 8218    522717347000  1460661635740 -360.0
# 8235    521475978500  1600470380438 -300.0
# 8329    507096545100  1460653401450 -360.0
# 8334    506798576820  1460653364950 -360.0
# 8348    505445203680  1415320665459    NaN
# 8418    490040428720  1415320611741    NaN
# 8541    469795974900  1460651705080 -360.0
# 8594    462731188500  1415320520759    NaN
# 8619    457110918730  1460651139690 -360.0
# 8646    448413971500  1415320478409    NaN
# 8762    445640071000  1528145025000    NaN
# 8938    426540545960  1415320407481    NaN
# 9003    412553375000  1415320354157    NaN
# 9048    403732430800  1460648111670 -360.0
# 9050    403732423040  1460648099510 -360.0
# 9067    402113188100  1460647984040 -360.0
# 9072    401753961500  1460661483750 -300.0
# 9073    401752669100  1460661477670 -300.0
# 9088    400068669400  1415320311661    NaN
# 9151    391866945430  1460647333490 -360.0
# 9166    389106327990  1460647211900 -360.0
# 9173    387854574890  1460647145050 -360.0
# 9209    378784825760  1415320236803    NaN
# 9225    375537266000  1415320225306    NaN
# 9235    374087478800  1460646683010 -360.0
# 9243    372594810500  1460646634400 -360.0
# 9320    366033224300  1528145025000 -360.0
# 9454    350499178800  1460645278680 -360.0
# 9502    344595570000  1528145025000 -360.0
# 9613    330804121500  1415316263647    NaN
# 9636    325197845700  1415316260655    NaN
# 9691    312439399000  1460643752490 -360.0
# 9733    305965443600  1415316125381    NaN
# 9747    303369536000  1415316124735    NaN
# 9989    273371460300  1460641817299 -360.0
# 10085   260146957700  1460641051250 -360.0
# 10110   254015186100  1460640885990 -360.0
# 10137   246441101700  1415316104867    NaN
# 10143   244791380900  1460640679210 -360.0
# 10163   238889001300  1415316103165    NaN
# 10504   173868493900  1460638360030 -360.0
# 10510   172481346600  1460638323520 -360.0
# 10531   169340585900  1415316090327    NaN
# 10539   168279778700  1415316090150    NaN
# 10718   132323428600  1415316083314    NaN
# 10719   132122059700  1415316083286    NaN
# 10722   126839557400  1415316082320    NaN
# 10723   125232300100  1415316081906    NaN
# 10724   123493721200  1594411064872    NaN
# 10725   120869919000  1415316081092    NaN
# 10734  -234899684300  1528145025000    NaN
# 10735  -249671790000  1528145025000    NaN
# 10739  -381902023000  1528145024000    NaN
# 10743  -420200649200  1528145024000    NaN
# 10744  -439413344500  1528145024000    NaN
# 10745  -465836240000  1528145024000    NaN
# 10751 -1298923030200  1528145024000    NaN
# 10758 -1616103900000  1528145024000    NaN
# 10762 -1791252600000  1528145024000    NaN
# 10767 -2087790120000  1528145024000    NaN
#
#                                                      url  \
# 8218   https://earthquake.usgs.gov/earthquakes/eventp...
# 8235   https://earthquake.usgs.gov/earthquakes/eventp...
# 8329   https://earthquake.usgs.gov/earthquakes/eventp...
# 8334   https://earthquake.usgs.gov/earthquakes/eventp...
# 8348   https://earthquake.usgs.gov/earthquakes/eventp...
# 8418   https://earthquake.usgs.gov/earthquakes/eventp...
# 8541   https://earthquake.usgs.gov/earthquakes/eventp...
# 8594   https://earthquake.usgs.gov/earthquakes/eventp...
# 8619   https://earthquake.usgs.gov/earthquakes/eventp...
# 8646   https://earthquake.usgs.gov/earthquakes/eventp...
# 8762   https://earthquake.usgs.gov/earthquakes/eventp...
# 8938   https://earthquake.usgs.gov/earthquakes/eventp...
# 9003   https://earthquake.usgs.gov/earthquakes/eventp...
# 9048   https://earthquake.usgs.gov/earthquakes/eventp...
# 9050   https://earthquake.usgs.gov/earthquakes/eventp...
# 9067   https://earthquake.usgs.gov/earthquakes/eventp...
# 9072   https://earthquake.usgs.gov/earthquakes/eventp...
# 9073   https://earthquake.usgs.gov/earthquakes/eventp...
# 9088   https://earthquake.usgs.gov/earthquakes/eventp...
# 9151   https://earthquake.usgs.gov/earthquakes/eventp...
# 9166   https://earthquake.usgs.gov/earthquakes/eventp...
# 9173   https://earthquake.usgs.gov/earthquakes/eventp...
# 9209   https://earthquake.usgs.gov/earthquakes/eventp...
# 9225   https://earthquake.usgs.gov/earthquakes/eventp...
# 9235   https://earthquake.usgs.gov/earthquakes/eventp...
# 9243   https://earthquake.usgs.gov/earthquakes/eventp...
# 9320   https://earthquake.usgs.gov/earthquakes/eventp...
# 9454   https://earthquake.usgs.gov/earthquakes/eventp...
# 9502   https://earthquake.usgs.gov/earthquakes/eventp...
# 9613   https://earthquake.usgs.gov/earthquakes/eventp...
# 9636   https://earthquake.usgs.gov/earthquakes/eventp...
# 9691   https://earthquake.usgs.gov/earthquakes/eventp...
# 9733   https://earthquake.usgs.gov/earthquakes/eventp...
# 9747   https://earthquake.usgs.gov/earthquakes/eventp...
# 9989   https://earthquake.usgs.gov/earthquakes/eventp...
# 10085  https://earthquake.usgs.gov/earthquakes/eventp...
# 10110  https://earthquake.usgs.gov/earthquakes/eventp...
# 10137  https://earthquake.usgs.gov/earthquakes/eventp...
# 10143  https://earthquake.usgs.gov/earthquakes/eventp...
# 10163  https://earthquake.usgs.gov/earthquakes/eventp...
# 10504  https://earthquake.usgs.gov/earthquakes/eventp...
# 10510  https://earthquake.usgs.gov/earthquakes/eventp...
# 10531  https://earthquake.usgs.gov/earthquakes/eventp...
# 10539  https://earthquake.usgs.gov/earthquakes/eventp...
# 10718  https://earthquake.usgs.gov/earthquakes/eventp...
# 10719  https://earthquake.usgs.gov/earthquakes/eventp...
# 10722  https://earthquake.usgs.gov/earthquakes/eventp...
# 10723  https://earthquake.usgs.gov/earthquakes/eventp...
# 10724  https://earthquake.usgs.gov/earthquakes/eventp...
# 10725  https://earthquake.usgs.gov/earthquakes/eventp...
# 10734  https://earthquake.usgs.gov/earthquakes/eventp...
# 10735  https://earthquake.usgs.gov/earthquakes/eventp...
# 10739  https://earthquake.usgs.gov/earthquakes/eventp...
# 10743  https://earthquake.usgs.gov/earthquakes/eventp...
# 10744  https://earthquake.usgs.gov/earthquakes/eventp...
# 10745  https://earthquake.usgs.gov/earthquakes/eventp...
# 10751  https://earthquake.usgs.gov/earthquakes/eventp...
# 10758  https://earthquake.usgs.gov/earthquakes/eventp...
# 10762  https://earthquake.usgs.gov/earthquakes/eventp...
# 10767  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                                   detail  felt  ...  gap  \
# 8218   https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 8235   https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 8329   https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 8334   https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 8348   https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 8418   https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 8541   https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 8594   https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 8619   https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 8646   https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 8762   https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 8938   https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 9003   https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 9048   https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 9050   https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 9067   https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 9072   https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 9073   https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 9088   https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 9151   https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 9166   https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 9173   https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 9209   https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 9225   https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 9235   https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 9243   https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 9320   https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 9454   https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 9502   https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 9613   https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 9636   https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 9691   https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 9733   https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 9747   https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 9989   https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 10085  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 10110  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 10137  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 10143  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 10163  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 10504  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 10510  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 10531  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 10539  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 10718  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 10719  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 10722  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 10723  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 10724  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 10725  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 10734  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 10735  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 10739  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 10743  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 10744  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 10745  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 10751  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 10758  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 10762  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
# 10767  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  NaN
#
#        magType        type                                           title  \
# 8218        md  earthquake           M 2.5 - 10km WNW of Linden, Tennessee
# 8235        md  earthquake        M 3.3 - 8km NE of Collegedale, Tennessee
# 8329        md  earthquake           M 2.5 - 9km SSE of Ridgely, Tennessee
# 8334        md  earthquake       M 2.5 - 12km NW of Tiptonville, Tennessee
# 8348        md  earthquake                       M 3.2 - eastern Tennessee
# 8418        md  earthquake                       M 3.0 - eastern Tennessee
# 8541        md  earthquake        M 2.6 - 10km WNW of Covington, Tennessee
# 8594        md  earthquake                       M 3.2 - eastern Tennessee
# 8619        md  earthquake           M 3.0 - 9km WNW of Newbern, Tennessee
# 8646        ml  earthquake                       M 3.0 - eastern Tennessee
# 8762        md  earthquake                       M 3.7 - eastern Tennessee
# 8938      mblg  earthquake                       M 3.3 - eastern Tennessee
# 9003      mblg  earthquake                       M 2.6 - eastern Tennessee
# 9048        md  earthquake             M 2.7 - 4km N of Ridgely, Tennessee
# 9050        md  earthquake           M 2.6 - 6km ESE of Ridgely, Tennessee
# 9067        md  earthquake           M 2.8 - 3km ESE of Ridgely, Tennessee
# 9072        md  earthquake          M 2.7 - 4km ESE of Kingston, Tennessee
# 9073        md  earthquake         M 2.5 - 5km WSW of Coalfield, Tennessee
# 9088      mblg  earthquake                       M 2.8 - eastern Tennessee
# 9151        md  earthquake       M 2.6 - 10km NW of Tiptonville, Tennessee
# 9166        md  earthquake         M 2.8 - 10km NW of Covington, Tennessee
# 9173        md  earthquake          M 2.8 - 12km NNW of Central, Tennessee
# 9209      mblg  earthquake                               M 2.9 - Tennessee
# 9225      mblg  earthquake                       M 2.6 - eastern Tennessee
# 9235        md  earthquake           M 3.0 - 5km N of Dyersburg, Tennessee
# 9243        md  earthquake           M 2.5 - 1km ESE of Ridgely, Tennessee
# 9320        md  earthquake           M 4.0 - 11km SE of Newbern, Tennessee
# 9454        md  earthquake         M 2.5 - 4km NNE of Covington, Tennessee
# 9502        md  earthquake            M 3.8 - 7km SE of Ridgely, Tennessee
# 9613      None  earthquake                       M 3.3 - eastern Tennessee
# 9636      None  earthquake                       M 2.6 - eastern Tennessee
# 9691       mlg  earthquake       M 2.5 - 5km WSW of Tiptonville, Tennessee
# 9733      None  earthquake                       M 3.2 - eastern Tennessee
# 9747      None  earthquake                       M 3.7 - eastern Tennessee
# 9989       mlg  earthquake         M 3.5 - 6km NNW of Dyersburg, Tennessee
# 10085      mlg  earthquake           M 2.6 - 1km ENE of Ridgely, Tennessee
# 10110      mlg  earthquake           M 2.6 - 6km ESE of Ridgely, Tennessee
# 10137     None  earthquake        M 2.8 - Tennessee-Virginia border region
# 10143      mlg  earthquake          M 3.0 - 12km ESE of Ridgely, Tennessee
# 10163     None  earthquake                       M 3.5 - eastern Tennessee
# 10504      mlg  earthquake             M 2.5 - 8km S of Ridgely, Tennessee
# 10510      mlg  earthquake            M 3.3 - 7km SE of Ridgely, Tennessee
# 10531       lg  earthquake                               M 2.7 - Tennessee
# 10539       lg  earthquake                       M 2.6 - eastern Tennessee
# 10718       lg  earthquake                               M 3.2 - Tennessee
# 10719       lg  earthquake                               M 2.5 - Tennessee
# 10722       mb  earthquake                               M 4.1 - Tennessee
# 10723       lg  earthquake                               M 3.4 - Tennessee
# 10724       mb  earthquake                       M 4.7 - eastern Tennessee
# 10725       lg  earthquake                       M 3.4 - eastern Tennessee
# 10734       mw  earthquake                               M 3.4 - Tennessee
# 10735       mw  earthquake                               M 4.2 - Tennessee
# 10739       fa  earthquake  M 3.9 - Tennessee-North Carolina border region
# 10743       fa  earthquake                       M 4.1 - eastern Tennessee
# 10744       fa  earthquake                               M 4.0 - Tennessee
# 10745       fa  earthquake                               M 3.9 - Tennessee
# 10751       lg  earthquake                       M 4.5 - eastern Tennessee
# 10758       fa  earthquake                               M 4.5 - Tennessee
# 10762       fa  earthquake                       M 4.1 - eastern Tennessee
# 10767       fa  earthquake                               M 4.6 - Tennessee
#
#        geometry_type     geometry_coordinates    TN longitude latitude depth
# 8218           Point     [-87.94, 35.66, 3.3]  True   -87.940   35.660   3.3
# 8235           Point       [-84.98, 35.11, 5]  True   -84.980   35.110   5.0
# 8329           Point  [-89.459, 36.183, 10.4]  True   -89.459   36.183  10.4
# 8334           Point    [-89.56, 36.466, 3.3]  True   -89.560   36.466   3.3
# 8348           Point  [-84.759, 35.606, 20.6]  True   -84.759   35.606  20.6
# 8418           Point    [-85.145, 35.192, 10]  True   -85.145   35.192  10.0
# 8541           Point    [-89.76, 35.59, 13.2]  True   -89.760   35.590  13.2
# 8594           Point    [-84.34, 35.56, 14.3]  True   -84.340   35.560  14.3
# 8619           Point    [-89.36, 36.149, 7.2]  True   -89.360   36.149   7.2
# 8646           Point     [-84.033, 35.814, 3]  True   -84.033   35.814   3.0
# 8762           Point   [-83.735, 36.121, 8.2]  True   -83.735   36.121   8.2
# 8938           Point  [-84.152, 35.544, 10.5]  True   -84.152   35.544  10.5
# 9003           Point  [-83.619, 36.054, 14.6]  True   -83.619   36.054  14.6
# 9048           Point     [-89.49, 36.3, 15.3]  True   -89.490   36.300  15.3
# 9050           Point       [-89.42, 36.24, 5]  True   -89.420   36.240   5.0
# 9067           Point       [-89.45, 36.25, 5]  True   -89.450   36.250   5.0
# 9072           Point      [-84.46, 35.86, 10]  True   -84.460   35.860  10.0
# 9073           Point      [-84.48, 36.01, 10]  True   -84.480   36.010  10.0
# 9088           Point  [-84.521, 35.202, 10.6]  True   -84.521   35.202  10.6
# 9151           Point     [-89.54, 36.46, 0.8]  True   -89.540   36.460   0.8
# 9166           Point    [-89.73, 35.63, 12.3]  True   -89.730   35.630  12.3
# 9173           Point       [-89.59, 35.91, 5]  True   -89.590   35.910   5.0
# 9209           Point       [-86.44, 35.19, 7]  True   -86.440   35.190   7.0
# 9225           Point     [-84.63, 35.64, 8.6]  True   -84.630   35.640   8.6
# 9235           Point    [-89.39, 36.08, 13.6]  True   -89.390   36.080  13.6
# 9243           Point     [-89.47, 36.26, 7.4]  True   -89.470   36.260   7.4
# 9320           Point    [-89.18, 36.03, 22.8]  True   -89.180   36.030  22.8
# 9454           Point     [-89.62, 35.6, 13.9]  True   -89.620   35.600  13.9
# 9502           Point    [-89.43, 36.21, 10.7]  True   -89.430   36.210  10.7
# 9613           Point     [-84.046, 35.779, 5]  True   -84.046   35.779   5.0
# 9636           Point      [-84.129, 35.76, 5]  True   -84.129   35.760   5.0
# 9691           Point     [-89.53, 36.36, 9.8]  True   -89.530   36.360   9.8
# 9733           Point     [-83.901, 35.587, 5]  True   -83.901   35.587   5.0
# 9747           Point     [-84.375, 35.243, 5]  True   -84.375   35.243   5.0
# 9989           Point     [-89.42, 36.09, 3.9]  True   -89.420   36.090   3.9
# 10085          Point     [-89.47, 36.27, 4.2]  True   -89.470   36.270   4.2
# 10110          Point       [-89.42, 36.25, 5]  True   -89.420   36.250   5.0
# 10137          Point     [-82.038, 36.972, 5]  True   -82.038   36.972   5.0
# 10143          Point       [-89.35, 36.24, 5]  True   -89.350   36.240   5.0
# 10163          Point      [-84.417, 35.42, 7]  True   -84.417   35.420   7.0
# 10504          Point       [-89.49, 36.19, 5]  True   -89.490   36.190   5.0
# 10510          Point     [-89.44, 36.21, 7.3]  True   -89.440   36.210   7.3
# 10531          Point     [-85.249, 35.947, 5]  True   -85.249   35.947   5.0
# 10539          Point    [-84.446, 35.921, 15]  True   -84.446   35.921  15.0
# 10718          Point       [-89.79, 35.66, 5]  True   -89.790   35.660   5.0
# 10719          Point       [-89.53, 36.21, 5]  True   -89.530   36.210   5.0
# 10722          Point        [-89.39, 36.2, 1]  True   -89.390   36.200   1.0
# 10723          Point     [-89.58, 36.157, 10]  True   -89.580   36.157  10.0
# 10724          Point     [-83.962, 35.799, 3]  True   -83.962   35.799   3.0
# 10725          Point         [-84, 35.75, 33]  True   -84.000   35.750  33.0
# 10734          Point     [-89.399, 36.044, 8]  True   -89.399   36.044   8.0
# 10735          Point     [-89.511, 36.374, 4]  True   -89.511   36.374   4.0
# 10739          Point        [-83.5, 35, None]  True   -83.500   35.000   NaN
# 10743          Point     [-83.787, 36.445, 5]  True   -83.787   36.445   5.0
# 10744          Point    [-89.803, 35.756, 16]  True   -89.803   35.756  16.0
# 10745          Point        [-89.5, 36, None]  True   -89.500   36.000   NaN
# 10751          Point     [-82.828, 36.112, 5]  True   -82.828   36.112   5.0
# 10758          Point        [-89.2, 36, None]  True   -89.200   36.000   NaN
# 10762          Point      [-83.7, 36.2, None]  True   -83.700   36.200   NaN
# 10767          Point      [-89.5, 36.5, None]  True   -89.500   36.500   NaN
#
# [60 rows x 34 columns]

# %%
usgs_tn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 324 entries, 403 to 10767
# Data columns (total 34 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  324 non-null    object
#  1   id                    324 non-null    object
#  2   mag                   324 non-null    float64
#  3   place                 324 non-null    object
#  4   time                  324 non-null    int64
#  5   updated               324 non-null    int64
#  6   tz                    265 non-null    float64
#  7   url                   324 non-null    object
#  8   detail                324 non-null    object
#  9   felt                  135 non-null    float64
#  10  cdi                   135 non-null    float64
#  11  mmi                   14 non-null     float64
#  12  alert                 4 non-null      object
#  13  status                324 non-null    object
#  14  tsunami               324 non-null    int64
#  15  sig                   324 non-null    int64
#  16  net                   324 non-null    object
#  17  code                  324 non-null    object
#  18  ids                   324 non-null    object
#  19  sources               324 non-null    object
#  20  types                 324 non-null    object
#  21  nst                   214 non-null    float64
#  22  dmin                  188 non-null    float64
#  23  rms                   220 non-null    float64
#  24  gap                   212 non-null    float64
#  25  magType               318 non-null    object
#  26  type                  324 non-null    object
#  27  title                 324 non-null    object
#  28  geometry_type         324 non-null    object
#  29  geometry_coordinates  324 non-null    object
#  30  TN                    324 non-null    bool
#  31  longitude             324 non-null    float64
#  32  latitude              324 non-null    float64
#  33  depth                 319 non-null    float64
# dtypes: bool(1), float64(12), int64(4), object(17)
# memory usage: 86.4+ KB

# %%
geometry = [Point(xy) for xy in zip(usgs_tn['longitude'], usgs_tn['latitude'])]

# %%
crs = {'init': 'epsg:4326'}
usgs_tn_geo = GeoDataFrame(usgs_tn, crs=crs, geometry=geometry)
# Out:
# /Users/turik1/opt/anaconda3/lib/python3.8/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
# 1175  https://earthquake.usgs.gov/earthquakes/eventp...
# 1200  https://earthquake.usgs.gov/earthquakes/eventp...
# 1217  https://earthquake.usgs.gov/earthquakes/eventp...
# 1220  https://earthquake.usgs.gov/earthquakes/eventp...
# 1228  https://earthquake.usgs.gov/earthquakes/eventp...
# 1229  https://earthquake.usgs.gov/earthquakes/eventp...
# 1233  https://earthquake.usgs.gov/earthquakes/eventp...
# 1262  https://earthquake.usgs.gov/earthquakes/eventp...
# 1264  https://earthquake.usgs.gov/earthquakes/eventp...
# 1309  https://earthquake.usgs.gov/earthquakes/eventp...
# 1391  https://earthquake.usgs.gov/earthquakes/eventp...
# 1392  https://earthquake.usgs.gov/earthquakes/eventp...
# 1430  https://earthquake.usgs.gov/earthquakes/eventp...
# 1539  https://earthquake.usgs.gov/earthquakes/eventp...
# 1561  https://earthquake.usgs.gov/earthquakes/eventp...
# 1586  https://earthquake.usgs.gov/earthquakes/eventp...
# 1592  https://earthquake.usgs.gov/earthquakes/eventp...
# 1610  https://earthquake.usgs.gov/earthquakes/eventp...
# 1740  https://earthquake.usgs.gov/earthquakes/eventp...
# 1794  https://earthquake.usgs.gov/earthquakes/eventp...
# 1843  https://earthquake.usgs.gov/earthquakes/eventp...
# 1861  https://earthquake.usgs.gov/earthquakes/eventp...
# 1872  https://earthquake.usgs.gov/earthquakes/eventp...
# 1875  https://earthquake.usgs.gov/earthquakes/eventp...
# 1878  https://earthquake.usgs.gov/earthquakes/eventp...
# 1886  https://earthquake.usgs.gov/earthquakes/eventp...
# 1890  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                                  detail     felt  ...  \
# 403   https://earthquake.usgs.gov/fdsnws/event/1/que...     34.0  ...
# 447   https://earthquake.usgs.gov/fdsnws/event/1/que...      1.0  ...
# 518   https://earthquake.usgs.gov/fdsnws/event/1/que...     16.0  ...
# 519   https://earthquake.usgs.gov/fdsnws/event/1/que...    138.0  ...
# 531   https://earthquake.usgs.gov/fdsnws/event/1/que...     89.0  ...
# 545   https://earthquake.usgs.gov/fdsnws/event/1/que...     10.0  ...
# 550   https://earthquake.usgs.gov/fdsnws/event/1/que...     12.0  ...
# 629   https://earthquake.usgs.gov/fdsnws/event/1/que...     48.0  ...
# 641   https://earthquake.usgs.gov/fdsnws/event/1/que...    105.0  ...
# 656   https://earthquake.usgs.gov/fdsnws/event/1/que...  10950.0  ...
# 657   https://earthquake.usgs.gov/fdsnws/event/1/que...     31.0  ...
# 662   https://earthquake.usgs.gov/fdsnws/event/1/que...      5.0  ...
# 676   https://earthquake.usgs.gov/fdsnws/event/1/que...      9.0  ...
# 692   https://earthquake.usgs.gov/fdsnws/event/1/que...      1.0  ...
# 806   https://earthquake.usgs.gov/fdsnws/event/1/que...      NaN  ...
# 807   https://earthquake.usgs.gov/fdsnws/event/1/que...      NaN  ...
# 924   https://earthquake.usgs.gov/fdsnws/event/1/que...     31.0  ...
# 944   https://earthquake.usgs.gov/fdsnws/event/1/que...     92.0  ...
# 1002  https://earthquake.usgs.gov/fdsnws/event/1/que...     37.0  ...
# 1010  https://earthquake.usgs.gov/fdsnws/event/1/que...      9.0  ...
# 1030  https://earthquake.usgs.gov/fdsnws/event/1/que...     10.0  ...
# 1039  https://earthquake.usgs.gov/fdsnws/event/1/que...      1.0  ...
# 1041  https://earthquake.usgs.gov/fdsnws/event/1/que...      6.0  ...
# 1053  https://earthquake.usgs.gov/fdsnws/event/1/que...   1327.0  ...
# 1056  https://earthquake.usgs.gov/fdsnws/event/1/que...      NaN  ...
# 1062  https://earthquake.usgs.gov/fdsnws/event/1/que...      7.0  ...
# 1063  https://earthquake.usgs.gov/fdsnws/event/1/que...      1.0  ...
# 1083  https://earthquake.usgs.gov/fdsnws/event/1/que...      9.0  ...
# 1122  https://earthquake.usgs.gov/fdsnws/event/1/que...   1709.0  ...
# 1127  https://earthquake.usgs.gov/fdsnws/event/1/que...      7.0  ...
# 1152  https://earthquake.usgs.gov/fdsnws/event/1/que...      NaN  ...
# 1153  https://earthquake.usgs.gov/fdsnws/event/1/que...      4.0  ...
# 1173  https://earthquake.usgs.gov/fdsnws/event/1/que...    331.0  ...
# 1175  https://earthquake.usgs.gov/fdsnws/event/1/que...     60.0  ...
# 1200  https://earthquake.usgs.gov/fdsnws/event/1/que...     27.0  ...
# 1217  https://earthquake.usgs.gov/fdsnws/event/1/que...    109.0  ...
# 1220  https://earthquake.usgs.gov/fdsnws/event/1/que...     10.0  ...
# 1228  https://earthquake.usgs.gov/fdsnws/event/1/que...    793.0  ...
# 1229  https://earthquake.usgs.gov/fdsnws/event/1/que...   9457.0  ...
# 1233  https://earthquake.usgs.gov/fdsnws/event/1/que...     13.0  ...
# 1262  https://earthquake.usgs.gov/fdsnws/event/1/que...      NaN  ...
# 1264  https://earthquake.usgs.gov/fdsnws/event/1/que...     30.0  ...
# 1309  https://earthquake.usgs.gov/fdsnws/event/1/que...     27.0  ...
# 1391  https://earthquake.usgs.gov/fdsnws/event/1/que...      NaN  ...
# 1392  https://earthquake.usgs.gov/fdsnws/event/1/que...      3.0  ...
# 1430  https://earthquake.usgs.gov/fdsnws/event/1/que...      8.0  ...
# 1539  https://earthquake.usgs.gov/fdsnws/event/1/que...      8.0  ...
# 1561  https://earthquake.usgs.gov/fdsnws/event/1/que...      7.0  ...
# 1586  https://earthquake.usgs.gov/fdsnws/event/1/que...    618.0  ...
# 1592  https://earthquake.usgs.gov/fdsnws/event/1/que...     27.0  ...
# 1610  https://earthquake.usgs.gov/fdsnws/event/1/que...      NaN  ...
# 1740  https://earthquake.usgs.gov/fdsnws/event/1/que...      6.0  ...
# 1794  https://earthquake.usgs.gov/fdsnws/event/1/que...      6.0  ...
# 1843  https://earthquake.usgs.gov/fdsnws/event/1/que...    414.0  ...
# 1861  https://earthquake.usgs.gov/fdsnws/event/1/que...      7.0  ...
# 1872  https://earthquake.usgs.gov/fdsnws/event/1/que...      1.0  ...
# 1875  https://earthquake.usgs.gov/fdsnws/event/1/que...    101.0  ...
# 1878  https://earthquake.usgs.gov/fdsnws/event/1/que...     40.0  ...
# 1886  https://earthquake.usgs.gov/fdsnws/event/1/que...      NaN  ...
# 1890  https://earthquake.usgs.gov/fdsnws/event/1/que...      7.0  ...
#
#       magType        type                                        title  \
# 403        md  earthquake       M 2.6 - 7 km ENE of Seymour, Tennessee
# 447        md  earthquake        M 2.5 - 1 km SW of Ridgely, Tennessee
# 518        md  earthquake        M 2.8 - 8km SSE of Sewanee, Tennessee
# 519        md  earthquake        M 3.1 - 7km SSE of Sewanee, Tennessee
# 531        md  earthquake       M 2.5 - 4km ENE of Rutledge, Tennessee
# 545        md  earthquake    M 2.7 - 3km SSE of Tiptonville, Tennessee
# 550        md  earthquake        M 2.7 - 7km ESE of Ridgely, Tennessee
# 629        md  earthquake      M 2.7 - 4km ENE of Fincastle, Tennessee
# 641        md  earthquake      M 2.8 - 9km NNW of Dyersburg, Tennessee
# 656        mb  earthquake      M 3.8 - 3km ENE of Fincastle, Tennessee
# 1794       md  earthquake       M 2.8 - 9km SSE of Rockwood, Tennessee
# 1843       md  earthquake     M 2.7 - 10km WSW of Knoxville, Tennessee
# 1861       md  earthquake    M 2.9 - 5km WNW of Tiptonville, Tennessee
# 1872       md  earthquake         M 2.5 - 5km SSW of Athens, Tennessee
# 1875       md  earthquake      M 2.7 - 8km N of Sevierville, Tennessee
# 1878       md  earthquake          M 3.1 - 4km N of Ridgely, Tennessee
# 1886       md  earthquake        M 2.7 - 7km N of Greenback, Tennessee
# 1890       md  earthquake    M 2.9 - 11km NW of Tiptonville, Tennessee
#
#      geometry_type              geometry_coordinates    TN  longitude  \
# 403          Point     [-83.6435, 35.9183333, 17.35]  True -83.643500
# 447          Point   [-89.4991667, 36.2566667, 9.43]  True -89.499167
# 518          Point           [-85.883, 35.142, 6.48]  True -85.883000
# 519          Point      [-85.8918333, 35.1405, 8.43]  True -85.891833
# 531          Point     [-83.4638333, 36.3036667, 15]  True -83.463833
# 545          Point       [-89.462, 36.3458333, 5.22]  True -89.462000
# 550          Point      [-89.4008333, 36.2485, 5.79]  True -89.400833
# 629          Point     [-84.0243333, 36.4295, 34.91]  True -84.024333
# 641          Point  [-89.4156667, 36.1051667, 11.74]  True -89.415667
# 656          Point     [-84.0268333, 36.4305, 34.84]  True -84.026833
# 657          Point  [-84.0281667, 36.4308333, 33.89]  True -84.028167
# 662          Point  [-89.4043333, 36.0621667, 11.56]  True -89.404333
# 676          Point   [-89.4698333, 36.2761667, 5.47]  True -89.469833
# 692          Point      [-84.7261667, 35.534, 15.93]  True -84.726167
# 806          Point   [-89.5078333, 36.2756667, 8.06]  True -89.507833
# 807          Point   [-89.5068333, 36.2771667, 8.35]  True -89.506833
# 924          Point         [-83.7395, 36.0385, 7.41]  True -83.739500
# 944          Point  [-83.6471667, 36.3906667, 13.13]  True -83.647167
# 1002         Point   [-86.0421667, 35.4623333, 6.45]  True -86.042167
# 1010         Point   [-89.5021667, 36.2811667, 9.56]  True -89.502167
# 1030         Point  [-84.3668333, 35.6908333, 20.63]  True -84.366833
# 1039         Point  [-84.4768333, 36.0778333, 12.17]  True -84.476833
# 1041         Point  [-84.2191667, 35.9181667, 12.05]  True -84.219167
# 1053         Point  [-89.4398333, 36.1358333, 14.16]  True -89.439833
# 1056         Point   [-89.5228333, 36.2893333, 8.68]  True -89.522833
# 1062         Point       [-89.458, 36.2148333, 9.32]  True -89.458000
# 1063         Point   [-89.4601667, 36.2081667, 8.11]  True -89.460167
# 1083         Point     [-89.4265, 36.1236667, 11.81]  True -89.426500
# 1122         Point     [-83.7356667, 36.2955, 17.07]  True -83.735667
# 1127         Point      [-89.4456667, 36.1885, 8.94]  True -89.445667
# 1152         Point  [-83.4743333, 36.2816667, 10.07]  True -83.474333
# 1153         Point  [-83.4758333, 36.2801667, 11.46]  True -83.475833
# 1173         Point   [-86.3088333, 35.4858333, 6.52]  True -86.308833
# 1175         Point  [-83.9556667, 35.7708333, 13.01]  True -83.955667
# 1041  35.918167  12.05  POINT (-84.21917 35.91817)
# 1053  36.135833  14.16  POINT (-89.43983 36.13583)
# 1056  36.289333   8.68  POINT (-89.52283 36.28933)
# 1062  36.214833   9.32  POINT (-89.45800 36.21483)
# 1063  36.208167   8.11  POINT (-89.46017 36.20817)
# 1083  36.123667  11.81  POINT (-89.42650 36.12367)
# 1122  36.295500  17.07  POINT (-83.73567 36.29550)
# 1127  36.188500   8.94  POINT (-89.44567 36.18850)
# 1152  36.281667  10.07  POINT (-83.47433 36.28167)
# 1153  36.280167  11.46  POINT (-83.47583 36.28017)
# 1173  35.485833   6.52  POINT (-86.30883 35.48583)
# 1175  35.770833  13.01  POINT (-83.95567 35.77083)
# 1200  35.491167  19.01  POINT (-84.14817 35.49117)
# 1217  36.038333  19.69  POINT (-83.69550 36.03833)
# 1220  36.146833   4.76  POINT (-83.75233 36.14683)
# 1228  35.602500   5.84  POINT (-84.73600 35.60250)
# 1229  35.612333   7.87  POINT (-84.73200 35.61233)
# 1233  35.679500  21.84  POINT (-84.56400 35.67950)
# 1262  36.445000   9.54  POINT (-89.53667 36.44500)
# 1264  36.448167   9.77  POINT (-89.53650 36.44817)
# 1309  36.271500   6.52  POINT (-89.44483 36.27150)
# 1391  36.474833   4.71  POINT (-89.46700 36.47483)
# 1392  36.475000   4.82  POINT (-89.46617 36.47500)
# 1430  35.397000  18.47  POINT (-84.42400 35.39700)
# 1539  35.606333   4.63  POINT (-84.72683 35.60633)
# 1561  35.863333  15.99  POINT (-84.29450 35.86333)
# 1586  36.296833  21.17  POINT (-83.38950 36.29683)
# 1592  36.026167   8.24  POINT (-83.78917 36.02617)
# 1610  36.070000  19.82  POINT (-83.65350 36.07000)
# 1740  36.318667  18.63  POINT (-83.70917 36.31867)
# 1794  35.784833  24.02  POINT (-84.64500 35.78483)
# 1843  35.934333  10.68  POINT (-84.03017 35.93433)
# 1861  36.392833   8.90  POINT (-89.53017 36.39283)
# 1872  35.403333  15.39  POINT (-84.62483 35.40333)
# 1875  35.945000  10.33  POINT (-83.56117 35.94500)
# 1878  36.306167   4.81  POINT (-89.49033 36.30617)
# 1886  35.725000  22.57  POINT (-84.16500 35.72500)
# 1890  36.450333  10.52  POINT (-89.57017 36.45033)
#
# [60 rows x 35 columns]

# %%
m = folium.Map([35.01, -85.27], zoom_start= 8, tiles='cartodbpositron')
folium.GeoJson(usgs_tn_geo).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from folium.plugins import MarkerCluster

m = folium.Map([40.01, -105.27], zoom_start= 8, tiles='cartodbpositron')

marker_cluster = MarkerCluster().add_to(m)

for point in range(0, len(geometry)):
    folium.Marker(location = geometry, popup='Features: ' + str(usgs_tn_geo['depth'][point]) + ' ' + str(usgs_tn_geo['mag'][point])).add_to(marker_cluster)

m
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-e0592c21997e> in <module>
#       6
#       7 for point in range(0, len(geometry)):
# ----> 8     folium.Marker(location = geometry, popup='Features: ' + str(usgs_tn_geo['depth'][point]) + ' ' + str(usgs_tn_geo['mag'][point])).add_to(marker_cluster)
#       9
#      10 m
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
#    4407             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
